# %%
import json
import os
import sys
from collections import defaultdict
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd

# Paths and inputs
repo = Path('..').resolve()
coverage_path = repo / 'coverage_table_updated.csv'
validation_path = repo / 'validation_results.csv'
candidates_path = repo / 'report_candidates.csv'

coverage = pd.read_csv(coverage_path, sep='\t')
candidates = pd.read_csv(candidates_path)

# Load validation results to skip already-validated reports
validated_df = pd.read_csv(validation_path)
validated_set = set(
    (row['CID'], row['Year']) 
    for _, row in validated_df[validated_df['Valid'] == True].iterrows()
)
print(f"✓ Already validated: {len(validated_set)} company-year combinations")

# Filter to incomplete rows that are NOT already validated
incomplete = coverage[coverage['Priority'] != 'Complete ✓'].copy()

def needs_download(row):
    return (row['Company_Identifier'], row['FiscalYear']) not in validated_set

incomplete = incomplete[incomplete.apply(needs_download, axis=1)]
incomplete = incomplete[['CompanyName', 'Company_Identifier', 'FiscalYear', 'IR_URL']]

print(f"→ Reports to download: {len(incomplete)}")
print(f"→ Candidates available: {len(candidates)}")

# Show summary by company
by_company = incomplete.groupby('CompanyName').size().sort_values(ascending=False)
print(f"\nCompanies needing downloads ({len(by_company)}):")
for company, count in by_company.head(10).items():
    print(f"  {company}: {count} years")
# Out:
# ✓ Already validated: 120 company-year combinations
# → Reports to download: 60
# → Candidates available: 43
#
# Companies needing downloads (18):
#   ABB Ltd: 6 years
#   Industrivärden C: 6 years
#   Sv. Handelsbanken A: 6 years
#   AstraZeneca: 6 years
#   Nordea Bank Abp: 6 years
#   NIBE Industrier B: 5 years
#   SEB A: 5 years
#   Hennes & Mauritz B: 4 years
#   Skanska B: 3 years
#   Swedbank A: 3 years

# %%
# Download PDFs using precomputed candidates from step 3
from aspiratio.utils.report_downloader import download_pdf

def download_company_year(cid, company, year, ir_url, company_candidates):
    """Download a single company-year report, trying all candidates."""
    result = {
        'cid': cid,
        'company': company,
        'year': year,
        'status': 'failed',
        'url': '',
        'source_page': ir_url,
        'error': '',
        'pages': 0,
        'size_mb': 0.0
    }
    
    if company_candidates.empty:
        result['error'] = 'No candidate URL for year'
        return result
    
    # Try each candidate until one succeeds
    for _, cand in company_candidates.iterrows():
        url = cand['URL']
        title = cand.get('Title', '')
        source_page = cand.get('Source_Page', ir_url) or ir_url
        output_path = repo / 'companies' / cid / f"{cid}_{year}_Annual_Report.pdf"
        
        # Create directory if needed
        output_path.parent.mkdir(parents=True, exist_ok=True)
        
        dl_result = download_pdf(url, str(output_path), year_hint=year)
        
        if dl_result.get('success'):
            result['status'] = 'success'
            result['url'] = url
            result['source_page'] = source_page
            result['title'] = title
            result['pages'] = dl_result.get('pages', 0)
            result['size_mb'] = dl_result.get('size_mb', 0.0)
            result['output_path'] = str(output_path)
            return result
        else:
            result['error'] = dl_result.get('error', 'download failed')
            result['url'] = url
    
    return result

# Build download tasks
download_tasks = []
for _, row in incomplete.iterrows():
    cid = row['Company_Identifier']
    company = row['CompanyName']
    year = int(row['FiscalYear'])
    ir_url = row['IR_URL']
    company_candidates = candidates[(candidates['Company_Identifier'] == cid) & (candidates['Year'] == year)]
    download_tasks.append((cid, company, year, ir_url, company_candidates))

print(f"📥 Starting downloads for {len(download_tasks)} reports...")

# Download in parallel (but limit to 3 concurrent to be respectful to servers)
download_results = []
max_workers = min(3, len(download_tasks)) if download_tasks else 1

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = {
        executor.submit(download_company_year, cid, company, year, ir_url, cands): (cid, company, year)
        for cid, company, year, ir_url, cands in download_tasks
    }
    
    for future in as_completed(futures):
        cid, company, year = futures[future]
        try:
            result = future.result()
            download_results.append(result)
            if result['status'] == 'success':
                print(f"  ✓ {company} ({cid}) {year}: {result['pages']} pages")
            else:
                print(f"  ✗ {company} ({cid}) {year}: {result['error']}")
        except Exception as e:
            print(f"  ✗ {company} ({cid}) {year}: Exception - {e}")
            download_results.append({
                'cid': cid, 'company': company, 'year': year,
                'status': 'failed', 'error': str(e)
            })

# Convert to DataFrame for easier analysis
results_df = pd.DataFrame(download_results)

# Persist summary
download_summary_path = repo / 'download_summary_from_candidates.json'
with open(download_summary_path, 'w') as f:
    json.dump(download_results, f, indent=2, default=str)

print(f"\n📊 Download summary saved to: {download_summary_path}")
results_df.head(100)
# Out:
# 📥 Starting downloads for 60 reports...
#   → Downloading from: https://mb.cision.com/Main/417/3296284/1379492.pdf
#   → Downloading from: https://mb.cision.com/Main/417/3516666/1542750.pdf
#   → Downloading from: https://mb.cision.com/Main/417/3045869/1201088.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2021_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2019_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   → Downloaded: 0.0 MB
#   → Validating PDF...
#   → Downloading from: https://mb.cision.com/Main/417/3725044/1882197.pdf
#   ✗ ABB Ltd (S1) 2021: Only 1 pages (min 50 required)
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2019: Only 1 pages (min 50 required)
#   → Downloading from: https://global.abb/content/dam/abb/global/group/investors/results-and-reports/annual_reporting_suite/2023/ABB%20Form%20SD%202023.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2020_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2020: Only 1 pages (min 50 required)
#   → URL doesn't end with .pdf, checking if it's an HTML page...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2023_Annual_Report.pdf
#   → Downloading from: https://storage.mfn.se/c/aHR0cHM6Ly9lcXMtY29ja3BpdC5jb20vYy9mbmNscy5zc3A_dT00MDI2YTgzODkzNmNjNjEyNTdhYzc3MDMxNzdiMjFiMw/pdf.pdf?news-id=32135482-caab-58e4-83bf-ae921012f2d8
#   → Downloaded: 0.4 MB
#   → Validating PDF...
#   → PDF has 23 pages
#   ✗ Only 23 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2023: Only 23 pages (min 50 required)
#   ✗ AstraZeneca (S5) 2019: No candidate URL for year
#   ✗ AstraZeneca (S5) 2020: No candidate URL for year
#   ✗ AstraZeneca (S5) 2021: No candidate URL for year
#   ✗ AstraZeneca (S5) 2022: No candidate URL for year
#   ✗ AstraZeneca (S5) 2023: No candidate URL for year
#   ✗ AstraZeneca (S5) 2024: No candidate URL for year
#   → Downloading from: https://mb.cision.com/Public/997/3056319/925822ca04929dc0.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2022_Annual_Report.pdf
#   → Downloaded: 0.0 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2022: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/15798/3154642/1279575.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2024_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2024: Only 2 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/15798/3274602/1364026.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S11/S11_2019_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S11/S11_2020_Annual_Report.pdf
#   🚫 HTTP 403 Forbidden - server may be blocking requests
#   → Retrying with different user agent...
#   Retry 1/3...
#   → Downloaded: 1.2 MB
#   → Validating PDF...
#   → PDF has 27 pages
#   ✗ Only 27 pages (min 50 required)
#   → Downloading from: https://hmgroup.com/wp-content/uploads/2025/03/HM-Group-Annual-and-sustainability-report-2024.pdf
#   ✗ Essity B (S11) 2019: Only 27 pages (min 50 required)
#   → Downloaded: 1.2 MB
#   → Validating PDF...
#   → PDF has 26 pages
#   ✗ Only 26 pages (min 50 required)
#   ✗ Essity B (S11) 2020: Only 26 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/769/3743344/1953371.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2022_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2020_Annual_Report.pdf
#   → Downloaded: 4.3 MB
#   → Validating PDF...
#   → PDF has 152 pages
#   ✓ Success: 152 pages, 4.3 MB
#   ✓ Hennes & Mauritz B (S13) 2022: 152 pages
#   → Downloading from: https://mb.cision.com/Main/769/3952727/2698038.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2023_Annual_Report.pdf
#   → Downloaded: 12.8 MB
#   → Validating PDF...
#   → PDF has 148 pages
#   ✓ Success: 148 pages, 12.8 MB
#   ✓ Hennes & Mauritz B (S13) 2023: 148 pages
#   → Downloading from: https://mb.cision.com/Main/769/4124721/3347739.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2024_Annual_Report.pdf
#   → Downloaded: 8.3 MB
#   → Validating PDF...
#   → PDF has 87 pages
#   ✓ Success: 87 pages, 8.3 MB
#   ✓ Hennes & Mauritz B (S13) 2020: 87 pages
#   ✗ Industrivärden C (S15) 2019: No candidate URL for year
#   → Downloading from: https://www.industrivarden.se/globalassets/arsredovisningar/engelska/annual-report_indu_2011_eng.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S15/S15_2020_Annual_Report.pdf
#   → Downloaded: 9.2 MB
#   → Validating PDF...
#   → PDF has 87 pages
#   ✓ Success: 87 pages, 9.2 MB
#   ✓ Hennes & Mauritz B (S13) 2024: 87 pages
#   ✗ Industrivärden C (S15) 2021: No candidate URL for year
#   ✗ Industrivärden C (S15) 2022: No candidate URL for year
#   ✗ Industrivärden C (S15) 2023: No candidate URL for year
#   ✗ Industrivärden C (S15) 2024: No candidate URL for year
#   → Downloading from: https://mb.cision.com/Main/1084/2775825/1016251.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S16/S16_2019_Annual_Report.pdf
#   → Downloaded: 0.2 MB
#   → Validating PDF...
#   → PDF has 12 pages
#   ✗ Only 12 pages (min 50 required)
#   ✗ Investor B (S16) 2019: Only 12 pages (min 50 required)
#   → Downloading from: https://network.s-z.se/app/uploads/sites/16/Lifco-annual-report-2017.pdf
#   → Downloading from: https://mb.cision.com/Public/997/3056319/925822ca04929dc0.pdf
#   🚫 HTTP 403 Forbidden - server may be blocking requests
#   → Retrying with different user agent...
#   Retry 2/3...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S17/S17_2020_Annual_Report.pdf
#   → Downloaded: 8.5 MB
#   → Validating PDF...
#   → PDF has 56 pages
#   ✓ Success: 56 pages, 8.5 MB
#   ✓ Industrivärden C (S15) 2020: 56 pages
#   ✗ NIBE Industrier B (S18) 2019: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2020: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2021: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2022: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2023: No candidate URL for year
#   → Downloading from: https://mb.cision.com/Main/434/3047655/1201947.pdf
#   → Downloaded: 3.4 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2019_Annual_Report.pdf
#   → PDF has 92 pages
#   ✓ Success: 92 pages, 3.4 MB
#   ✓ Lifco B (S17) 2020: 92 pages
#   → Downloading from: https://mb.cision.com/Main/434/3297563/1380411.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2020_Annual_Report.pdf
#   → Downloaded: 7.8 MB
#   → Validating PDF...
#   → PDF has 296 pages
#   ✓ Success: 296 pages, 7.8 MB
#   ✓ Nordea Bank Abp (S19) 2019: 296 pages
#   → Downloading from: https://mb.cision.com/Public/434/3517156/a676509631b85d17.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2021_Annual_Report.pdf
#   → Downloaded: 10.8 MB
#   → Validating PDF...
#   → PDF has 292 pages
#   ✓ Success: 292 pages, 10.8 MB
#   ✓ Nordea Bank Abp (S19) 2020: 292 pages
#   → Downloading from: https://mb.cision.com/Public/434/3725516/812c3dee2915cff3.pdf
#   → Downloaded: 3.7 MB
#   → Validating PDF...
#   → PDF has 11 pages
#   ✗ Only 11 pages (min 50 required)
#   ✗ Nordea Bank Abp (S19) 2021: Only 11 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/434/3935418/2626561.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2022_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2023_Annual_Report.pdf
#   → Downloading from: https://mb.cision.com/Public/997/3056319/925822ca04929dc0.pdf
#   → Downloaded: 8.7 MB
#   → Validating PDF...
#   → PDF has 364 pages
#   🚫 HTTP 403 Forbidden - server may be blocking requests
#   ✗ Boliden (S7) 2019: HTTP 403
#   → URL doesn't end with .pdf, checking if it's an HTML page...
#   ✓ Success: 364 pages, 8.7 MB
#   ✓ Nordea Bank Abp (S19) 2022: 364 pages
#   → Downloading from: https://mb.cision.com/Main/208/3058294/1210382.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S21/S21_2019_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ Sandvik (S21) 2019: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/600/3520131/1545335.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S22/S22_2021_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ SCA B (S22) 2021: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/4324/3222287/1323639.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2019_Annual_Report.pdf
#   → Downloaded: 0.0 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ SEB A (S23) 2019: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/4324/3298906/1381441.pdf
#   → Downloaded: 9.2 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2020_Annual_Report.pdf
# ignore '/Perms' verify failed
#   → Downloaded: 0.0 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ SEB A (S23) 2020: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/4324/3516765/1542756.pdf
#   → Downloading from: https://www.nordea.com/en/doc/annual-report-nordea-bank-abp-2024-0.pdf#page=5
#   → PDF has 386 pages
#   ✓ Success: 386 pages, 9.2 MB
#   ✓ Nordea Bank Abp (S19) 2023: 386 pages
#   → Downloading from: https://mb.cision.com/Main/4324/3724878/1881092.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2021_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2022_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   ✗ SEB A (S23) 2021: Only 2 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/4324/3936474/2631963.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   ✗ SEB A (S23) 2022: Only 2 pages (min 50 required)
#   ✗ Skanska B (S24) 2019: No candidate URL for year
#   → Downloading from: https://mb.cision.com/Main/95/3069349/1218328.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2024_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S24/S24_2020_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/95/3497789/1528995.pdf
#   ✗ SEB A (S23) 2023: Only 2 pages (min 50 required)
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 3 pages
#   ✗ Only 3 pages (min 50 required)
#   ✗ Skanska B (S24) 2020: Only 3 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/637/3052162/1205531.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S24/S24_2021_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S25/S25_2019_Annual_Report.pdf
#   → Downloaded: 0.3 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ SKF B (S25) 2019: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/3555/3035159/1193715.pdf
#   → Downloaded: 13.5 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2019_Annual_Report.pdf
#   → PDF has 384 pages
#   ✓ Success: 384 pages, 13.5 MB
#   ✓ Nordea Bank Abp (S19) 2024: 384 pages
#   → Downloading from: https://mb.cision.com/Main/3555/3194745/1306735.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2020_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/3555/3519940/1545190.pdf
#   ✗ Sv. Handelsbanken A (S26) 2020: Only 1 pages (min 50 required)
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2021_Annual_Report.pdf
#   → Downloaded: 2.5 MB
#   → Validating PDF...
#   → PDF has 260 pages
#   ✓ Success: 260 pages, 2.5 MB
#   → Downloading from: https://mb.cision.com/Main/3555/3723067/1874784.pdf
#   ✓ Sv. Handelsbanken A (S26) 2019: 260 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2022_Annual_Report.pdf
#   → Downloaded: 5.7 MB
#   → Validating PDF...
#   → PDF has 284 pages
#   ✓ Success: 284 pages, 5.7 MB
#   ✓ Sv. Handelsbanken A (S26) 2021: 284 pages
#   → Downloading from: https://mb.cision.com/Main/3555/3934274/2623353.pdf
#   → Downloaded: 6.2 MB
#   → Validating PDF...
#   → PDF has 30 pages
#   ✗ Only 30 pages (min 50 required)
#   ✗ Skanska B (S24) 2021: Only 30 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/3555/4111826/3288310.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2024_Annual_Report.pdf
#   → Downloaded: 5.1 MB
#   → Validating PDF...
#   → PDF has 272 pages
#   ✓ Success: 272 pages, 5.1 MB
#   ✓ Sv. Handelsbanken A (S26) 2022: 272 pages
#   → Downloading from: https://mb.cision.com/Main/67/3039111/1196760.pdf
#   → Downloaded: 4.2 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S27/S27_2019_Annual_Report.pdf
#   → PDF has 312 pages
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/67/3365325/1430768.pdf
#   ✗ Swedbank A (S27) 2019: Only 1 pages (min 50 required)
#   ✓ Success: 312 pages, 4.2 MB
#   ✓ Sv. Handelsbanken A (S26) 2023: 312 pages
#   → Downloading from: https://mb.cision.com/Main/67/3978851/2794734.pdf
#   → Downloaded: 6.7 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S27/S27_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S27/S27_2020_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → Downloaded: 0.2 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ Swedbank A (S27) 2023: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/40/3229596/1329189.pdf
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/40/4089761/3199587.pdf
#   ✗ Swedbank A (S27) 2020: Only 2 pages (min 50 required)
#   → PDF has 388 pages
#   ✓ Success: 388 pages, 6.7 MB
#   ✓ Sv. Handelsbanken A (S26) 2024: 388 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S29/S29_2020_Annual_Report.pdf  → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S29/S29_2024_Annual_Report.pdf
#
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 4 pages
#   ✗ Only 4 pages (min 50 required)
#   ✗ Telia Company (S29) 2020: Only 4 pages (min 50 required)
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ Telia Company (S29) 2024: Only 1 pages (min 50 required)
#
# 📊 Download summary saved to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/download_summary_from_candidates.json
#   cid      company  year  status  \
# 0  S1      ABB Ltd  2021  failed
# 1  S1      ABB Ltd  2019  failed
# 2  S1      ABB Ltd  2020  failed
# 3  S1      ABB Ltd  2023  failed
# 4  S5  AstraZeneca  2019  failed
# 5  S5  AstraZeneca  2020  failed
# 6  S5  AstraZeneca  2021  failed
# 7  S5  AstraZeneca  2022  failed
# 8  S5  AstraZeneca  2023  failed
# 9  S5  AstraZeneca  2024  failed
#
#                                                  url  \
# 0  https://mb.cision.com/Main/417/3516666/1542750...
# 1  https://mb.cision.com/Main/417/3045869/1201088...
# 2  https://mb.cision.com/Main/417/3296284/1379492...
# 3  https://global.abb/content/dam/abb/global/grou...
# 4
# 5
# 6
# 7
# 8
# 9
#
#                                          source_page  \
# 0              https://global.abb/group/en/investors
# 1              https://global.abb/group/en/investors
# 2              https://global.abb/group/en/investors
# 3              https://global.abb/group/en/investors
# 4  https://www.astrazeneca.com/investor-relations...
# 5  https://www.astrazeneca.com/investor-relations...
# 6  https://www.astrazeneca.com/investor-relations...
# 7  https://www.astrazeneca.com/investor-relations...
# 8  https://www.astrazeneca.com/investor-relations...
# 9  https://www.astrazeneca.com/investor-relations...
#
#                              error  pages  size_mb title output_path
# 0   Only 1 pages (min 50 required)      0      0.0   NaN         NaN
# 1   Only 1 pages (min 50 required)      0      0.0   NaN         NaN
# 2   Only 1 pages (min 50 required)      0      0.0   NaN         NaN
# 3  Only 23 pages (min 50 required)      0      0.0   NaN         NaN
# 4        No candidate URL for year      0      0.0   NaN         NaN
# 5        No candidate URL for year      0      0.0   NaN         NaN
# 6        No candidate URL for year      0      0.0   NaN         NaN
# 7        No candidate URL for year      0      0.0   NaN         NaN
# 8        No candidate URL for year      0      0.0   NaN         NaN
# 9        No candidate URL for year      0      0.0   NaN         NaN

# %%
results_df.head(100)
# Out:
#     cid              company  year   status  \
# 0    S1              ABB Ltd  2021   failed
# 1    S1              ABB Ltd  2019   failed
# 2    S1              ABB Ltd  2020   failed
# 3    S1              ABB Ltd  2023   failed
# 4    S5          AstraZeneca  2019   failed
# 5    S5          AstraZeneca  2020   failed
# 6    S5          AstraZeneca  2021   failed
# 7    S5          AstraZeneca  2022   failed
# 8    S5          AstraZeneca  2023   failed
# 9    S5          AstraZeneca  2024   failed
# 10   S1              ABB Ltd  2022   failed
# 11   S1              ABB Ltd  2024   failed
# 12  S11             Essity B  2019   failed
# 13  S11             Essity B  2020   failed
# 14  S13   Hennes & Mauritz B  2022  success
# 15  S13   Hennes & Mauritz B  2023  success
# 16  S13   Hennes & Mauritz B  2020  success
# 17  S15     Industrivärden C  2019   failed
# 18  S13   Hennes & Mauritz B  2024  success
# 19  S15     Industrivärden C  2021   failed
# 20  S15     Industrivärden C  2022   failed
# 21  S15     Industrivärden C  2023   failed
# 22  S15     Industrivärden C  2024   failed
# 23  S16           Investor B  2019   failed
# 24  S15     Industrivärden C  2020  success
# 25  S18    NIBE Industrier B  2019   failed
# 26  S18    NIBE Industrier B  2020   failed
# 27  S18    NIBE Industrier B  2021   failed
# 28  S18    NIBE Industrier B  2022   failed
# 29  S18    NIBE Industrier B  2023   failed
# 30  S17              Lifco B  2020  success
# 31  S19      Nordea Bank Abp  2019  success
# 32  S19      Nordea Bank Abp  2020  success
# 33  S19      Nordea Bank Abp  2021   failed
# 34   S7              Boliden  2019   failed
# 35  S19      Nordea Bank Abp  2022  success
# 36  S21              Sandvik  2019   failed
# 37  S22                SCA B  2021   failed
# 38  S23                SEB A  2019   failed
# 39  S23                SEB A  2020   failed
# 40  S19      Nordea Bank Abp  2023  success
# 41  S23                SEB A  2021   failed
# 42  S23                SEB A  2022   failed
# 43  S24            Skanska B  2019   failed
# 44  S23                SEB A  2023   failed
# 45  S24            Skanska B  2020   failed
# 46  S25                SKF B  2019   failed
# 47  S19      Nordea Bank Abp  2024  success
# 48  S26  Sv. Handelsbanken A  2020   failed
# 49  S26  Sv. Handelsbanken A  2019  success
# 50  S26  Sv. Handelsbanken A  2021  success
# 51  S24            Skanska B  2021   failed
# 52  S26  Sv. Handelsbanken A  2022  success
# 53  S27           Swedbank A  2019   failed
# 54  S26  Sv. Handelsbanken A  2023  success
# 55  S27           Swedbank A  2023   failed
# 56  S27           Swedbank A  2020   failed
# 57  S26  Sv. Handelsbanken A  2024  success
# 58  S29        Telia Company  2020   failed
# 59  S29        Telia Company  2024   failed
#
#                                                   url  \
# 0   https://mb.cision.com/Main/417/3516666/1542750...
# 1   https://mb.cision.com/Main/417/3045869/1201088...
# 2   https://mb.cision.com/Main/417/3296284/1379492...
# 3   https://global.abb/content/dam/abb/global/grou...
# 4
# 5
# 6
# 7
# 8
# 9
# 10  https://mb.cision.com/Main/417/3725044/1882197...
# 11  https://storage.mfn.se/c/aHR0cHM6Ly9lcXMtY29ja...
# 12  https://mb.cision.com/Main/15798/3154642/12795...
# 13  https://mb.cision.com/Main/15798/3274602/13640...
# 14  https://mb.cision.com/Main/769/3743344/1953371...
# 15  https://mb.cision.com/Main/769/3952727/2698038...
# 16  https://hmgroup.com/wp-content/uploads/2025/03...
# 17
# 18  https://mb.cision.com/Main/769/4124721/3347739...
# 19
# 20
# 21
# 22
# 23  https://mb.cision.com/Main/1084/2775825/101625...
# 24  https://www.industrivarden.se/globalassets/ars...
# 25
# 26
# 27
# 28
# 29
# 30  https://network.s-z.se/app/uploads/sites/16/Li...
# 31  https://mb.cision.com/Main/434/3047655/1201947...
# 32  https://mb.cision.com/Main/434/3297563/1380411...
# 33  https://mb.cision.com/Public/434/3517156/a6765...
# 34  https://mb.cision.com/Public/997/3056319/92582...
# 35  https://mb.cision.com/Public/434/3725516/812c3...
# 36  https://mb.cision.com/Main/208/3058294/1210382...
# 37  https://mb.cision.com/Main/600/3520131/1545335...
# 38  https://mb.cision.com/Main/4324/3222287/132363...
# 39  https://mb.cision.com/Main/4324/3298906/138144...
# 40  https://mb.cision.com/Main/434/3935418/2626561...
# 41  https://mb.cision.com/Main/4324/3516765/154275...
# 42  https://mb.cision.com/Main/4324/3724878/188109...
# 43
# 44  https://mb.cision.com/Main/4324/3936474/263196...
# 45  https://mb.cision.com/Main/95/3069349/1218328.pdf
# 46  https://mb.cision.com/Main/637/3052162/1205531...
# 47  https://www.nordea.com/en/doc/annual-report-no...
# 48  https://mb.cision.com/Main/3555/3194745/130673...
# 49  https://mb.cision.com/Main/3555/3035159/119371...
# 50  https://mb.cision.com/Main/3555/3519940/154519...
# 51  https://mb.cision.com/Main/95/3497789/1528995.pdf
# 52  https://mb.cision.com/Main/3555/3723067/187478...
# 53  https://mb.cision.com/Main/67/3039111/1196760.pdf
# 54  https://mb.cision.com/Main/3555/3934274/262335...
# 55  https://mb.cision.com/Main/67/3978851/2794734.pdf
# 56  https://mb.cision.com/Main/67/3365325/1430768.pdf
# 57  https://mb.cision.com/Main/3555/4111826/328831...
# 58  https://mb.cision.com/Main/40/3229596/1329189.pdf
# 59  https://mb.cision.com/Main/40/4089761/3199587.pdf
#
#                                           source_page  \
# 0               https://global.abb/group/en/investors
# 1               https://global.abb/group/en/investors
# 2               https://global.abb/group/en/investors
# 3               https://global.abb/group/en/investors
# 4   https://www.astrazeneca.com/investor-relations...
# 5   https://www.astrazeneca.com/investor-relations...
# 6   https://www.astrazeneca.com/investor-relations...
# 7   https://www.astrazeneca.com/investor-relations...
# 8   https://www.astrazeneca.com/investor-relations...
# 9   https://www.astrazeneca.com/investor-relations...
# 10              https://global.abb/group/en/investors
# 11              https://global.abb/group/en/investors
# 12                  https://www.essity.com/investors/
# 13                  https://www.essity.com/investors/
# 14  https://news.cision.com/se/h---m-hennes---maur...
# 15  https://news.cision.com/se/h---m-hennes---maur...
# 16                     https://hmgroup.com/investors/
# 17  https://www.industrivarden.se/investerare/rapp...
# 18  https://news.cision.com/se/h---m-hennes---maur...
# 19  https://www.industrivarden.se/investerare/rapp...
# 20  https://www.industrivarden.se/investerare/rapp...
# 21  https://www.industrivarden.se/investerare/rapp...
# 22  https://www.industrivarden.se/investerare/rapp...
# 23  https://www.investorab.com/investors-media/rep...
# 24  https://www.industrivarden.se/en-gb/investors/...
# 25                     https://www.nibe.com/investors
# 26                     https://www.nibe.com/investors
# 27                     https://www.nibe.com/investors
# 28                     https://www.nibe.com/investors
# 29                     https://www.nibe.com/investors
# 30  https://www.lifco.se/investors/financial-repor...
# 31  https://news.cision.com/nordea/r/nordea-has-pu...
# 32  https://news.cision.com/nordea/r/nordea-has-pu...
# 33                https://www.nordea.com/en/investors
# 34                     https://investors.boliden.com/
# 35  https://news.cision.com/nordea/r/nordea-has-pu...
# 36             https://www.home.sandvik/en/investors/
# 37                  https://www.sca.com/en/investors/
# 38            https://sebgroup.com/investor-relations
# 39            https://sebgroup.com/investor-relations
# 40  https://news.cision.com/nordea/r/nordea-has-pu...
# 41            https://sebgroup.com/investor-relations
# 42            https://sebgroup.com/investor-relations
# 43               https://group.skanska.com/investors/
# 44            https://sebgroup.com/investor-relations
# 45               https://group.skanska.com/investors/
# 46               https://www.skf.com/group/investors/
# 47  https://www.nordea.com/en/investors/latest-ann...
# 48  https://www.handelsbanken.com/sv/investor-rela...
# 49  https://news.cision.com/handelsbanken/r/handel...
# 50  https://news.cision.com/handelsbanken/r/handel...
# 51               https://group.skanska.com/investors/
# 52  https://news.cision.com/handelsbanken/r/handel...
# 53  https://www.swedbank.com/investor-relations/th...
# 54  https://news.cision.com/handelsbanken/r/handel...
# 55  https://www.swedbank.com/investor-relations/th...
# 56  https://www.swedbank.com/investor-relations/th...
# 57  https://news.cision.com/handelsbanken/r/handel...
# 58          https://www.teliacompany.com/en/investors
# 59          https://www.teliacompany.com/en/investors
#
#                               error  pages    size_mb  \
# 0    Only 1 pages (min 50 required)      0   0.000000
# 1    Only 1 pages (min 50 required)      0   0.000000
# 2    Only 1 pages (min 50 required)      0   0.000000
# 3   Only 23 pages (min 50 required)      0   0.000000
# 4         No candidate URL for year      0   0.000000
# 5         No candidate URL for year      0   0.000000
# 6         No candidate URL for year      0   0.000000
# 7         No candidate URL for year      0   0.000000
# 8         No candidate URL for year      0   0.000000
# 9         No candidate URL for year      0   0.000000
# 10   Only 1 pages (min 50 required)      0   0.000000
# 11   Only 2 pages (min 50 required)      0   0.000000
# 12  Only 27 pages (min 50 required)      0   0.000000
# 13  Only 26 pages (min 50 required)      0   0.000000
# 14                                     152   4.324619
# 15                                     148  12.812410
# 16                                      87   8.288708
# 17        No candidate URL for year      0   0.000000
# 18                                      87   9.223759
# 19        No candidate URL for year      0   0.000000
# 20        No candidate URL for year      0   0.000000
# 21        No candidate URL for year      0   0.000000
# 22        No candidate URL for year      0   0.000000
# 23  Only 12 pages (min 50 required)      0   0.000000
# 24                                      56   8.546265
# 25        No candidate URL for year      0   0.000000
# 26        No candidate URL for year      0   0.000000
# 27        No candidate URL for year      0   0.000000
# 28        No candidate URL for year      0   0.000000
# 29        No candidate URL for year      0   0.000000
# 30                                      92   3.398388
# 31                                     296   7.797473
# 32                                     292  10.786964
# 33  Only 11 pages (min 50 required)      0   0.000000
# 34                         HTTP 403      0   0.000000
# 35                                     364   8.706219
# 36   Only 1 pages (min 50 required)      0   0.000000
# 37   Only 1 pages (min 50 required)      0   0.000000
# 38   Only 1 pages (min 50 required)      0   0.000000
# 39   Only 1 pages (min 50 required)      0   0.000000
# 40                                     386   9.187355
# 41   Only 2 pages (min 50 required)      0   0.000000
# 42   Only 2 pages (min 50 required)      0   0.000000
# 43        No candidate URL for year      0   0.000000
# 44   Only 2 pages (min 50 required)      0   0.000000
# 45   Only 3 pages (min 50 required)      0   0.000000
# 46   Only 1 pages (min 50 required)      0   0.000000
# 47                                     384  13.541471
# 48   Only 1 pages (min 50 required)      0   0.000000
# 49                                     260   2.455250
# 50                                     284   5.671917
# 51  Only 30 pages (min 50 required)      0   0.000000
# 52                                     272   5.122626
# 53   Only 1 pages (min 50 required)      0   0.000000
# 54                                     312   4.237366
# 55   Only 1 pages (min 50 required)      0   0.000000
# 56   Only 2 pages (min 50 required)      0   0.000000
# 57                                     388   6.735518
# 58   Only 4 pages (min 50 required)      0   0.000000
# 59   Only 1 pages (min 50 required)      0   0.000000
#
#                                                 title  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  h & m hennes & mauritz ab:s års- och hållbarhe...
# 15  h & m hennes & mauritz ab:s års- och hållbarhe...
# 16              annual and sustainability report 2024
# 17                                                NaN
# 18  h & m hennes & mauritz ab publicerar sin års- ...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                               2011
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  nordea has published its annual report, sustai...
# 32  nordea has published its annual report, sustai...
# 33                                                NaN
# 34                                                NaN
# 35  nordea has published its annual reporting for ...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  nordea has published its annual reporting for ...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                   read ceo comment
# 48                                                NaN
# 49  handelsbanken publishes its annual report for ...
# 50  handelsbanken publishes its annual and sustain...
# 51                                                NaN
# 52  handelsbanken publishes its annual and sustain...
# 53                                                NaN
# 54  handelsbanken publishes its annual and sustain...
# 55                                                NaN
# 56                                                NaN
# 57  handelsbanken publishes its annual and sustain...
# 58                                                NaN
# 59                                                NaN
#
#                                           output_path
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /Users/jakobjohannesson/Documents/github_repos...
# 15  /Users/jakobjohannesson/Documents/github_repos...
# 16  /Users/jakobjohannesson/Documents/github_repos...
# 17                                                NaN
# 18  /Users/jakobjohannesson/Documents/github_repos...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  /Users/jakobjohannesson/Documents/github_repos...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  /Users/jakobjohannesson/Documents/github_repos...
# 31  /Users/jakobjohannesson/Documents/github_repos...
# 32  /Users/jakobjohannesson/Documents/github_repos...
# 33                                                NaN
# 34                                                NaN
# 35  /Users/jakobjohannesson/Documents/github_repos...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  /Users/jakobjohannesson/Documents/github_repos...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47  /Users/jakobjohannesson/Documents/github_repos...
# 48                                                NaN
# 49  /Users/jakobjohannesson/Documents/github_repos...
# 50  /Users/jakobjohannesson/Documents/github_repos...
# 51                                                NaN
# 52  /Users/jakobjohannesson/Documents/github_repos...
# 53                                                NaN
# 54  /Users/jakobjohannesson/Documents/github_repos...
# 55                                                NaN
# 56                                                NaN
# 57  /Users/jakobjohannesson/Documents/github_repos...
# 58                                                NaN
# 59                                                NaN

# %%
# Summarize download outcomes
successes = results_df[results_df['status'] == 'success']
failures = results_df[results_df['status'] == 'failed']

print('Download Summary')
print('=' * 50)
print(f"✓ Successful downloads: {len(successes)}")
print(f"✗ Failed downloads: {len(failures)}")
print(f"Total attempted: {len(results_df)}")

if len(successes) > 0:
    print(f"\nSuccessful downloads:")
    for _, row in successes.iterrows():
        pages = row.get('pages', '?')
        print(f"  ✓ {row['company']} ({row['cid']}) {row['year']}: {pages} pages")

if len(failures) > 0:
    print(f"\nFailed downloads (by error type):")
    error_counts = failures.groupby('error').size().sort_values(ascending=False)
    for error, count in error_counts.items():
        print(f"  • {error}: {count}")
    
    print(f"\nFailed details:")
    for _, row in failures.iterrows():
        print(f"  ✗ {row['company']} ({row['cid']}) {row['year']}: {row['error']}")
# Out:
# Download Summary
# ==================================================
# ✓ Successful downloads: 16
# ✗ Failed downloads: 44
# Total attempted: 60
#
# Successful downloads:
#   ✓ Hennes & Mauritz B (S13) 2022: 152 pages
#   ✓ Hennes & Mauritz B (S13) 2023: 148 pages
#   ✓ Hennes & Mauritz B (S13) 2020: 87 pages
#   ✓ Hennes & Mauritz B (S13) 2024: 87 pages
#   ✓ Industrivärden C (S15) 2020: 56 pages
#   ✓ Lifco B (S17) 2020: 92 pages
#   ✓ Nordea Bank Abp (S19) 2019: 296 pages
#   ✓ Nordea Bank Abp (S19) 2020: 292 pages
#   ✓ Nordea Bank Abp (S19) 2022: 364 pages
#   ✓ Nordea Bank Abp (S19) 2023: 386 pages
#   ✓ Nordea Bank Abp (S19) 2024: 384 pages
#   ✓ Sv. Handelsbanken A (S26) 2019: 260 pages
#   ✓ Sv. Handelsbanken A (S26) 2021: 284 pages
#   ✓ Sv. Handelsbanken A (S26) 2022: 272 pages
#   ✓ Sv. Handelsbanken A (S26) 2023: 312 pages
#   ✓ Sv. Handelsbanken A (S26) 2024: 388 pages
#
# Failed downloads (by error type):
#   • No candidate URL for year: 17
#   • Only 1 pages (min 50 required): 13
#   • Only 2 pages (min 50 required): 5
#   • HTTP 403: 1
#   • Only 11 pages (min 50 required): 1
#   • Only 12 pages (min 50 required): 1
#   • Only 23 pages (min 50 required): 1
#   • Only 26 pages (min 50 required): 1
#   • Only 27 pages (min 50 required): 1
#   • Only 3 pages (min 50 required): 1
#   • Only 30 pages (min 50 required): 1
#   • Only 4 pages (min 50 required): 1
#
# Failed details:
#   ✗ ABB Ltd (S1) 2021: Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2019: Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2020: Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2023: Only 23 pages (min 50 required)
#   ✗ AstraZeneca (S5) 2019: No candidate URL for year
#   ✗ AstraZeneca (S5) 2020: No candidate URL for year
#   ✗ AstraZeneca (S5) 2021: No candidate URL for year
#   ✗ AstraZeneca (S5) 2022: No candidate URL for year
#   ✗ AstraZeneca (S5) 2023: No candidate URL for year
#   ✗ AstraZeneca (S5) 2024: No candidate URL for year
#   ✗ ABB Ltd (S1) 2022: Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2024: Only 2 pages (min 50 required)
#   ✗ Essity B (S11) 2019: Only 27 pages (min 50 required)
#   ✗ Essity B (S11) 2020: Only 26 pages (min 50 required)
#   ✗ Industrivärden C (S15) 2019: No candidate URL for year
#   ✗ Industrivärden C (S15) 2021: No candidate URL for year
#   ✗ Industrivärden C (S15) 2022: No candidate URL for year
#   ✗ Industrivärden C (S15) 2023: No candidate URL for year
#   ✗ Industrivärden C (S15) 2024: No candidate URL for year
#   ✗ Investor B (S16) 2019: Only 12 pages (min 50 required)
#   ✗ NIBE Industrier B (S18) 2019: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2020: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2021: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2022: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2023: No candidate URL for year
#   ✗ Nordea Bank Abp (S19) 2021: Only 11 pages (min 50 required)
#   ✗ Boliden (S7) 2019: HTTP 403
#   ✗ Sandvik (S21) 2019: Only 1 pages (min 50 required)
#   ✗ SCA B (S22) 2021: Only 1 pages (min 50 required)
#   ✗ SEB A (S23) 2019: Only 1 pages (min 50 required)
#   ✗ SEB A (S23) 2020: Only 1 pages (min 50 required)
#   ✗ SEB A (S23) 2021: Only 2 pages (min 50 required)
#   ✗ SEB A (S23) 2022: Only 2 pages (min 50 required)
#   ✗ Skanska B (S24) 2019: No candidate URL for year
#   ✗ SEB A (S23) 2023: Only 2 pages (min 50 required)
#   ✗ Skanska B (S24) 2020: Only 3 pages (min 50 required)
#   ✗ SKF B (S25) 2019: Only 1 pages (min 50 required)
#   ✗ Sv. Handelsbanken A (S26) 2020: Only 1 pages (min 50 required)
#   ✗ Skanska B (S24) 2021: Only 30 pages (min 50 required)
#   ✗ Swedbank A (S27) 2019: Only 1 pages (min 50 required)
#   ✗ Swedbank A (S27) 2023: Only 1 pages (min 50 required)
#   ✗ Swedbank A (S27) 2020: Only 2 pages (min 50 required)
#   ✗ Telia Company (S29) 2020: Only 4 pages (min 50 required)
#   ✗ Telia Company (S29) 2024: Only 1 pages (min 50 required)

# %%
# Validate successful downloads, copy to companies_validated/{CID}/, and update coverage table
import importlib.util
from datetime import datetime

# Load validation function from scripts
validate_script_path = repo / 'scripts' / 'validate_reports.py'
spec = importlib.util.spec_from_file_location("validate_reports", validate_script_path)
validate_module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(validate_module)
validate_pdf = validate_module.validate_pdf

# Setup directories
validated_dir = repo / 'companies_validated'
validated_dir.mkdir(exist_ok=True)

# Reload coverage table (in case it was modified)
coverage_df = pd.read_csv(coverage_path, sep='\t')

validation_records = []

for _, dl in successes.iterrows():
    cid = dl['cid']
    company = dl['company']
    year = dl['year']
    output_path = dl.get('output_path', '')
    
    if not output_path:
        output_path = str(repo / 'companies' / cid / f"{cid}_{year}_Annual_Report.pdf")
    
    pdf_path = Path(output_path)
    
    if not pdf_path.exists():
        validation_records.append({
            'company': company, 'cid': cid, 'year': year,
            'valid': False, 'issues': 'file missing after download'
        })
        print(f"⚠ Missing file: {pdf_path}")
        continue

    # Run validation
    validation = validate_pdf(str(pdf_path), company_name=company, expected_year=year)
    is_valid = validation.get('valid', False)
    issues = '; '.join(validation.get('issues', [])) if validation.get('issues') else ''
    size_mb = os.path.getsize(pdf_path) / (1024 * 1024)
    
    validation_records.append({
        'company': company, 'cid': cid, 'year': year,
        'valid': is_valid, 'issues': issues,
        'confidence': validation.get('confidence'),
        'pages': validation.get('pages'),
        'size_mb': size_mb
    })

    if is_valid:
        # Copy to validated directory
        dest_dir = validated_dir / cid
        dest_dir.mkdir(exist_ok=True)
        dest_path = dest_dir / pdf_path.name
        dest_path.write_bytes(pdf_path.read_bytes())
        print(f"✓ Validated: {company} {year} ({validation.get('pages')} pages, {validation.get('confidence'):.1f}% confidence)")

        # Update coverage table
        mask = (coverage_df['Company_Identifier'] == cid) & (coverage_df['FiscalYear'] == year)
        coverage_df.loc[mask, 'Report_URL'] = dl.get('url', '')
        coverage_df.loc[mask, 'Source_Page'] = dl.get('source_page', '')
        coverage_df.loc[mask, 'Pages'] = validation.get('pages', '')
        coverage_df.loc[mask, 'Size_MB'] = f"{size_mb:.2f}"
        coverage_df.loc[mask, 'Validation_Status'] = 'Valid'
        coverage_df.loc[mask, 'Validation_Confidence'] = f"{validation.get('confidence', 0.0):.1f}%"
        coverage_df.loc[mask, 'Validation_Issues'] = issues
        coverage_df.loc[mask, 'Validation_Date'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        coverage_df.loc[mask, 'Priority'] = 'Complete ✓'
        coverage_df.loc[mask, 'CaptureStatus'] = 'Validated'
    else:
        print(f"✗ Failed validation: {company} {year} ({issues})")

# Summary
print('\n' + '=' * 50)
print('Validation Summary')
print('=' * 50)
valid_count = sum(1 for r in validation_records if r['valid'])
print(f"✓ Valid: {valid_count} / {len(validation_records)}")
print(f"✗ Invalid: {len(validation_records) - valid_count}")

if any(not r['valid'] for r in validation_records):
    print('\nInvalid reports:')
    for r in validation_records:
        if not r['valid']:
            print(f"  ✗ {r['company']} ({r['cid']}) {r['year']}: {r.get('issues','')}")

# Save updated coverage table
coverage_df.to_csv(coverage_path, sep='\t', index=False)
print(f"\n✓ Coverage table updated: {coverage_path}")
# Out:
# ✓ Validated: Hennes & Mauritz B 2022 (152 pages, 87.2% confidence)
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.32' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'Size_MB'] = f"{size_mb:.2f}"
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:70: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'Validation_Issues'] = issues
# ✓ Validated: Hennes & Mauritz B 2023 (148 pages, 86.1% confidence)
# ✓ Validated: Hennes & Mauritz B 2020 (87 pages, 69.9% confidence)
# ✓ Validated: Hennes & Mauritz B 2024 (87 pages, 69.9% confidence)
# ✗ Failed validation: Industrivärden C 2020 (Year 2020 not found in PDF)
# ✗ Failed validation: Lifco B 2020 (Year 2020 not found in PDF)
# ✗ Failed validation: Nordea Bank Abp 2019 (Company name "Nordea Bank Abp" not found in PDF)
# ✗ Failed validation: Nordea Bank Abp 2020 (Company name "Nordea Bank Abp" not found in PDF)
# ✗ Failed validation: Nordea Bank Abp 2022 (Company name "Nordea Bank Abp" not found in PDF)
# ignore '/Perms' verify failed
# ignore '/Perms' verify failed
# ✗ Failed validation: Nordea Bank Abp 2023 (Company name "Nordea Bank Abp" not found in PDF)
# ✗ Failed validation: Nordea Bank Abp 2024 (Company name "Nordea Bank Abp" not found in PDF)
# ✗ Failed validation: Sv. Handelsbanken A 2019 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✗ Failed validation: Sv. Handelsbanken A 2021 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✗ Failed validation: Sv. Handelsbanken A 2022 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✗ Failed validation: Sv. Handelsbanken A 2023 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✗ Failed validation: Sv. Handelsbanken A 2024 (Company name "Sv. Handelsbanken A" not found in PDF)
#
# ==================================================
# Validation Summary
# ==================================================
# ✓ Valid: 4 / 16
# ✗ Invalid: 12
#
# Invalid reports:
#   ✗ Industrivärden C (S15) 2020: Year 2020 not found in PDF
#   ✗ Lifco B (S17) 2020: Year 2020 not found in PDF
#   ✗ Nordea Bank Abp (S19) 2019: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Nordea Bank Abp (S19) 2020: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Nordea Bank Abp (S19) 2022: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Nordea Bank Abp (S19) 2023: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Nordea Bank Abp (S19) 2024: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2019: Company name "Sv. Handelsbanken A" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2021: Company name "Sv. Handelsbanken A" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2022: Company name "Sv. Handelsbanken A" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2023: Company name "Sv. Handelsbanken A" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2024: Company name "Sv. Handelsbanken A" not found in PDF
#
# ✓ Coverage table updated: /Users/jakobjohannesson/Documents/github_repos/aspiratio/coverage_table_updated.csv

# %%
# Append new validation records to validation_results.csv
if validation_records:
    new_records = []
    for r in validation_records:
        if r['valid']:
            cid = r['cid']
            year = r['year']
            company = r['company']
            pdf_name = f"{cid}_{year}_Annual_Report.pdf"
            
            # Find the download result for this record
            dl_info = successes[(successes['cid'] == cid) & (successes['year'] == year)].iloc[0] if len(successes[(successes['cid'] == cid) & (successes['year'] == year)]) > 0 else {}
            
            new_records.append({
                'CID': cid,
                'Company_Name': company,
                'Year': year,
                'Filename': pdf_name,
                'Valid': True,
                'Confidence': r.get('confidence', 0),
                'Pages': r.get('pages', 0),
                'Company_Found': True,
                'Year_Found': True,
                'Issues': r.get('issues', ''),
                'Source_Path': f"companies/{cid}/{pdf_name}",
                'Validated_Date': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
                'IR_URL': dl_info.get('source_page', '') if isinstance(dl_info, dict) else (dl_info['source_page'] if 'source_page' in dl_info.index else ''),
                'Pattern_Type': 'Downloaded via notebook'
            })
    
    if new_records:
        # Load existing validation results
        existing_validation = pd.read_csv(validation_path)
        new_df = pd.DataFrame(new_records)
        
        # Remove duplicates (in case we're re-running)
        existing_keys = set(zip(existing_validation['CID'], existing_validation['Year']))
        new_df = new_df[~new_df.apply(lambda r: (r['CID'], r['Year']) in existing_keys, axis=1)]
        
        if len(new_df) > 0:
            updated_validation = pd.concat([existing_validation, new_df], ignore_index=True)
            updated_validation.to_csv(validation_path, index=False)
            print(f"✓ Added {len(new_df)} new records to validation_results.csv")
        else:
            print("ℹ All validated records already exist in validation_results.csv")
else:
    print("ℹ No validation records to add")
# Out:
# ✓ Added 4 new records to validation_results.csv
