# %%
import json
import os
import sys
from collections import defaultdict
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd

# Paths and inputs
repo = Path('..').resolve()
coverage_path = repo / 'coverage_table_updated.csv'
validation_path = repo / 'validation_results.csv'
candidates_path = repo / 'report_candidates.csv'

coverage = pd.read_csv(coverage_path, sep='\t')
candidates = pd.read_csv(candidates_path)

# Load validation results to skip already-validated reports
validated_df = pd.read_csv(validation_path)
validated_set = set(
    (row['CID'], row['Year']) 
    for _, row in validated_df[validated_df['Valid'] == True].iterrows()
)
print(f"✓ Already validated: {len(validated_set)} company-year combinations")

# Filter to incomplete rows that are NOT already validated
incomplete = coverage[coverage['Priority'] != 'Complete ✓'].copy()

def needs_download(row):
    return (row['Company_Identifier'], row['FiscalYear']) not in validated_set

incomplete = incomplete[incomplete.apply(needs_download, axis=1)]
incomplete = incomplete[['CompanyName', 'Company_Identifier', 'FiscalYear', 'IR_URL']]

print(f"→ Reports to download: {len(incomplete)}")
print(f"→ Candidates available: {len(candidates)}")

# Show summary by company
by_company = incomplete.groupby('CompanyName').size().sort_values(ascending=False)
print(f"\nCompanies needing downloads ({len(by_company)}):")
for company, count in by_company.head(10).items():
    print(f"  {company}: {count} years")
# Out:
# ✓ Already validated: 0 company-year combinations
# → Reports to download: 180
# → Candidates available: 176
#
# Companies needing downloads (30):
#   ABB Ltd: 6 years
#   ASSA ABLOY B: 6 years
#   Telia Company: 6 years
#   Tele2 B: 6 years
#   Swedbank A: 6 years
#   Sv. Handelsbanken A: 6 years
#   Skanska B: 6 years
#   Sandvik: 6 years
#   SKF B: 6 years
#   SEB A: 6 years

# %%
# Download PDFs using precomputed candidates from step 3
from aspiratio.utils.report_downloader import download_pdf

def download_company_year(cid, company, year, ir_url, company_candidates):
    """Download a single company-year report, trying all candidates."""
    result = {
        'cid': cid,
        'company': company,
        'year': year,
        'status': 'failed',
        'url': '',
        'source_page': ir_url,
        'error': '',
        'pages': 0,
        'size_mb': 0.0
    }
    
    if company_candidates.empty:
        result['error'] = 'No candidate URL for year'
        return result
    
    # Try each candidate until one succeeds
    for _, cand in company_candidates.iterrows():
        url = cand['URL']
        title = cand.get('Title', '')
        source_page = cand.get('Source_Page', ir_url) or ir_url
        output_path = repo / 'companies' / cid / f"{cid}_{year}_Annual_Report.pdf"
        
        # Create directory if needed
        output_path.parent.mkdir(parents=True, exist_ok=True)
        
        dl_result = download_pdf(url, str(output_path), year_hint=year)
        
        if dl_result.get('success'):
            result['status'] = 'success'
            result['url'] = url
            result['source_page'] = source_page
            result['title'] = title
            result['pages'] = dl_result.get('pages', 0)
            result['size_mb'] = dl_result.get('size_mb', 0.0)
            result['output_path'] = str(output_path)
            return result
        else:
            result['error'] = dl_result.get('error', 'download failed')
            result['url'] = url
    
    return result

# Build download tasks
download_tasks = []
for _, row in incomplete.iterrows():
    cid = row['Company_Identifier']
    company = row['CompanyName']
    year = int(row['FiscalYear'])
    ir_url = row['IR_URL']
    company_candidates = candidates[(candidates['Company_Identifier'] == cid) & (candidates['Year'] == year)]
    download_tasks.append((cid, company, year, ir_url, company_candidates))

print(f"📥 Starting downloads for {len(download_tasks)} reports...")

# Download in parallel (but limit to 3 concurrent to be respectful to servers)
download_results = []
max_workers = min(3, len(download_tasks)) if download_tasks else 1

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = {
        executor.submit(download_company_year, cid, company, year, ir_url, cands): (cid, company, year)
        for cid, company, year, ir_url, cands in download_tasks
    }
    
    for future in as_completed(futures):
        cid, company, year = futures[future]
        try:
            result = future.result()
            download_results.append(result)
            if result['status'] == 'success':
                print(f"  ✓ {company} ({cid}) {year}: {result['pages']} pages")
            else:
                print(f"  ✗ {company} ({cid}) {year}: {result['error']}")
        except Exception as e:
            print(f"  ✗ {company} ({cid}) {year}: Exception - {e}")
            download_results.append({
                'cid': cid, 'company': company, 'year': year,
                'status': 'failed', 'error': str(e)
            })

# Convert to DataFrame for easier analysis
results_df = pd.DataFrame(download_results)

# Persist summary
download_summary_path = repo / 'download_summary_from_candidates.json'
with open(download_summary_path, 'w') as f:
    json.dump(download_results, f, indent=2, default=str)

print(f"\n📊 Download summary saved to: {download_summary_path}")
results_df.head(10)
# Out:
# 📥 Starting downloads for 180 reports...
#   → Downloading from: https://mb.cision.com/Main/417/3045869/1201088.pdf
#   → Downloading from: https://mb.cision.com/Main/417/3296284/1379492.pdf
#   → Downloading from: https://mb.cision.com/Main/417/3516666/1542750.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2021_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2019_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2020_Annual_Report.pdf
#   → Downloaded: 0.0 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → Downloading from: https://mb.cision.com/Main/417/3725044/1882197.pdf
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2019: Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2021: Only 1 pages (min 50 required)
#   → Downloading from: https://global.abb/content/dam/abb/global/group/investors/results-and-reports/annual_reporting_suite/2023/ABB%20Form%20SD%202023.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2020: Only 1 pages (min 50 required)
#   → URL doesn't end with .pdf, checking if it's an HTML page...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2022_Annual_Report.pdf
#   → Downloaded: 0.0 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2022: Only 1 pages (min 50 required)
#   → Downloading from: https://www.addtech.com/fileadmin/user_upload/Addtech-Annual-Report-2019-2020.pdf
#   → Downloading from: https://storage.mfn.se/c/aHR0cHM6Ly9lcXMtY29ja3BpdC5jb20vYy9mbmNscy5zc3A_dT00MDI2YTgzODkzNmNjNjEyNTdhYzc3MDMxNzdiMjFiMw/pdf.pdf?news-id=32135482-caab-58e4-83bf-ae921012f2d8
#   → Downloaded: 0.4 MB
#   → Validating PDF...
#   → PDF has 23 pages
#   ✗ Only 23 pages (min 50 required)
#   → Downloading from: https://www.addtech.com/fileadmin/user_upload/Addtech-Annual-Report-2020-2021.pdf
#   ✗ ABB Ltd (S1) 2023: Only 23 pages (min 50 required)
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S1/S1_2024_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2024: Only 2 pages (min 50 required)
#   → Downloading from: https://www.addtech.com/fileadmin/user_upload/Arsredovisningar/Addtech-Annual-Report-2021-2022.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S2/S2_2019_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S2/S2_2020_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S2/S2_2021_Annual_Report.pdf
#   → Downloaded: 11.2 MB
#   → Validating PDF...
#   → PDF has 61 pages
#   ✓ Success: 61 pages, 11.2 MB
#   → Downloading from: https://www.addtech.com/fileadmin/user_upload/Arsredovisningar/Addtech-Annual-Report-22-23.pdf
#   ✓ Addtech B (S2) 2019: 61 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S2/S2_2022_Annual_Report.pdf
#   → Downloaded: 13.5 MB
#   → Validating PDF...
#   → PDF has 74 pages
#   ✓ Success: 74 pages, 13.5 MB
#   ✓ Addtech B (S2) 2020: 74 pages
#   → Downloading from: https://www.addtech.com/fileadmin/user_upload/Addtech-Annual-Report-23-24.pdf
#   → Downloaded: 12.5 MB
#   → Validating PDF...
#   → PDF has 74 pages
#   ✓ Success: 74 pages, 12.5 MB
#   ✓ Addtech B (S2) 2021: 74 pages
#   → Downloading from: https://www.addtech.com/fileadmin/user_upload/Arsredovisningar/Addtech-Annual-Report-24-25.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S2/S2_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S2/S2_2024_Annual_Report.pdf
#   → Downloaded: 14.2 MB
#   → Validating PDF...
#   → PDF has 80 pages
#   ✓ Success: 80 pages, 14.2 MB
#   ✓ Addtech B (S2) 2022: 80 pages
#   → Downloading from: https://mb.cision.com/Main/905/3069338/1218261.pdf
#   → Downloaded: 7.5 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S3/S3_2019_Annual_Report.pdf
#   → PDF has 152 pages
#   ✓ Success: 152 pages, 7.5 MB
#   ✓ Addtech B (S2) 2024: 152 pages
#   → Downloading from: https://mb.cision.com/Main/905/3318163/1395815.pdf
#   → Downloaded: 11.4 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S3/S3_2020_Annual_Report.pdf
#   → PDF has 155 pages
#   ✓ Success: 155 pages, 11.4 MB
#   ✓ Addtech B (S2) 2023: 155 pages
#   → Downloading from: https://mb.cision.com/Main/905/3536813/1557177.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S3/S3_2021_Annual_Report.pdf
#   → Downloaded: 8.6 MB
#   → Validating PDF...
#   → PDF has 152 pages
#   ✓ Success: 152 pages, 8.6 MB
#   ✓ Alfa Laval (S3) 2019: 152 pages
#   → Downloading from: https://mb.cision.com/Main/905/3744039/1955700.pdf
#   → Downloaded: 3.8 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S3/S3_2022_Annual_Report.pdf
#   → PDF has 160 pages
#   ✓ Success: 160 pages, 3.8 MB
#   → Downloading from: https://mb.cision.com/Main/905/3953677/2701033.pdf
#   ✓ Alfa Laval (S3) 2020: 160 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S3/S3_2023_Annual_Report.pdf
#   → Downloaded: 6.9 MB
#   → Validating PDF...
#   → PDF has 194 pages
#   ✓ Success: 194 pages, 6.9 MB
#   ✓ Alfa Laval (S3) 2021: 194 pages
#   → Downloading from: https://mb.cision.com/Main/905/4128721/3359435.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S3/S3_2024_Annual_Report.pdf
#   → Downloaded: 6.3 MB
#   → Validating PDF...
#   → PDF has 192 pages
#   ✓ Success: 192 pages, 6.3 MB
#   ✓ Alfa Laval (S3) 2023: 192 pages
#   → Downloading from: https://www.assaabloy.com/group/en/documents/investors/annual-reports/2019/Annual%20report%202019.pdf
#   → Downloaded: 4.8 MB
#   → Validating PDF...
#   → PDF has 81 pages
#   ✓ Success: 81 pages, 4.8 MB
#   ✓ Alfa Laval (S3) 2024: 81 pages
#   → Downloading from: https://www.assaabloy.com/group/en/documents/investors/annual-reports/2020/Annual%20report%202020.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S4/S4_2019_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S4/S4_2020_Annual_Report.pdf
#   → Downloaded: 10.6 MB
#   → Validating PDF...
#   → PDF has 200 pages
#   ✓ Success: 200 pages, 10.6 MB
#   → Downloading from: https://www.assaabloy.com/group/en/documents/investors/annual-reports/2021/Annual%20report%202021.pdf
#   ✓ Alfa Laval (S3) 2022: 200 pages
#   → Downloaded: 5.4 MB
#   → Validating PDF...
#   → PDF has 108 pages
#   ✓ Success: 108 pages, 5.4 MB
#   ✓ ASSA ABLOY B (S4) 2019: 108 pages
#   → Downloading from: https://www.assaabloy.com/group/en/documents/investors/annual-reports/2022/Annual%20Report%202022.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S4/S4_2022_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S4/S4_2021_Annual_Report.pdf
#   → Downloaded: 7.2 MB
#   → Validating PDF...
#   → PDF has 112 pages
#   ✓ Success: 112 pages, 7.2 MB
#   ✓ ASSA ABLOY B (S4) 2020: 112 pages
#   → Downloading from: https://www.assaabloy.com/group/en/documents/investors/annual-reports/2023/Annual%20Report%202023.pdf
#   → Downloaded: 5.2 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S4/S4_2023_Annual_Report.pdf
#   → PDF has 116 pages
#   ✓ Success: 116 pages, 5.2 MB
#   ✓ ASSA ABLOY B (S4) 2022: 116 pages
#   → Downloading from: https://www.assaabloy.com/group/en/documents/investors/annual-reports/2024/Annual%20Report%202024.pdf
#   → Downloaded: 6.2 MB
#   → Validating PDF...
#   → PDF has 116 pages
#   ✓ Success: 116 pages, 6.2 MB
#   ✓ ASSA ABLOY B (S4) 2021: 116 pages
#   ✗ AstraZeneca (S5) 2019: No candidate URL for year
#   ✗ AstraZeneca (S5) 2020: No candidate URL for year
#   ✗ AstraZeneca (S5) 2021: No candidate URL for year
#   ✗ AstraZeneca (S5) 2022: No candidate URL for year
#   ✗ AstraZeneca (S5) 2023: No candidate URL for year
#   ✗ AstraZeneca (S5) 2024: No candidate URL for year
#   → Downloading from: https://mb.cision.com/Main/90/3053634/1206606.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S4/S4_2024_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S6/S6_2019_Annual_Report.pdf
#   → Downloaded: 9.4 MB
#   → Validating PDF...
#   → PDF has 116 pages
#   ✓ Success: 116 pages, 9.4 MB
#   → Downloading from: https://mb.cision.com/Main/90/3303771/1384842.pdf
#   ✓ ASSA ABLOY B (S4) 2023: 116 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S6/S6_2020_Annual_Report.pdf
#   → Downloaded: 12.5 MB
#   → Validating PDF...
#   → PDF has 164 pages
#   ✓ Success: 164 pages, 12.5 MB
#   ✓ ASSA ABLOY B (S4) 2024: 164 pages
#   → Downloading from: https://mb.cision.com/Main/90/3528089/1551058.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S6/S6_2021_Annual_Report.pdf
#   → Downloaded: 9.8 MB
#   → Validating PDF...
#   → PDF has 144 pages
#   ✓ Success: 144 pages, 9.8 MB
#   ✓ Atlas Copco A (S6) 2020: 144 pages
#   → Downloading from: https://mb.cision.com/Main/90/3737551/1929255.pdf
#   → Downloaded: 6.9 MB
#   → Validating PDF...
#   → PDF has 150 pages
#   ✓ Success: 150 pages, 6.9 MB
#   → Downloading from: https://mb.cision.com/Main/90/3949217/2683988.pdf
#   ✓ Atlas Copco A (S6) 2019: 150 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S6/S6_2022_Annual_Report.pdf
#   → Downloaded: 15.3 MB
#   → Validating PDF...
#   → PDF has 148 pages
#   ✓ Success: 148 pages, 15.3 MB
#   → Downloading from: https://mb.cision.com/Main/90/4121385/3330927.pdf
#   ✓ Atlas Copco A (S6) 2021: 148 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S6/S6_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S6/S6_2024_Annual_Report.pdf
#   → Downloaded: 8.7 MB
#   → Validating PDF...
#   → PDF has 152 pages
#   ✓ Success: 152 pages, 8.7 MB
#   ✓ Atlas Copco A (S6) 2022: 152 pages
#   → Downloading from: https://mb.cision.com/Public/997/3056299/97db413f283398d8.pdf
#   🚫 HTTP 403 Forbidden - server may be blocking requests
#   → Retrying with different user agent...
#   Retry 1/3...
#   → Downloaded: 10.1 MB
#   → Validating PDF...
#   → PDF has 169 pages
#   ✓ Success: 169 pages, 10.1 MB
#   ✓ Atlas Copco A (S6) 2024: 169 pages
#   → Downloading from: https://mb.cision.com/Main/997/3302961/1384337.pdf
#   → Downloaded: 10.2 MB
#   → Validating PDF...
#   → PDF has 154 pages
#   ✓ Success: 154 pages, 10.2 MB
#   ✓ Atlas Copco A (S6) 2023: 154 pages
#   → Downloading from: https://mb.cision.com/Main/997/3521171/1545927.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S7/S7_2020_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S7/S7_2021_Annual_Report.pdf
#   → Downloaded: 12.6 MB
#   → Validating PDF...
#   → PDF has 124 pages
#   ✓ Success: 124 pages, 12.6 MB
#   → Downloading from: https://mb.cision.com/Main/997/3728993/1896716.pdf
#   ✓ Boliden (S7) 2020: 124 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S7/S7_2022_Annual_Report.pdf
#   → Downloaded: 8.1 MB
#   → Validating PDF...
#   → PDF has 128 pages
#   ✓ Success: 128 pages, 8.1 MB
#   ✓ Boliden (S7) 2021: 128 pages
#   → Downloading from: https://mb.cision.com/Main/997/3940837/2649391.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S7/S7_2023_Annual_Report.pdf
#   → Downloaded: 7.4 MB
#   → Validating PDF...
#   → PDF has 136 pages
#   ✓ Success: 136 pages, 7.4 MB
#   → Downloading from: https://mb.cision.com/Main/997/4121044/3330967.pdf
#   ✓ Boliden (S7) 2022: 136 pages
#   → Downloading from: https://mb.cision.com/Public/997/3056299/97db413f283398d8.pdf
#   🚫 HTTP 403 Forbidden - server may be blocking requests
#   → Retrying with different user agent...
#   Retry 2/3...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S7/S7_2024_Annual_Report.pdf
#   → Downloaded: 8.7 MB
#   → Validating PDF...
#   → PDF has 144 pages
#   ✓ Success: 144 pages, 8.7 MB
#   ✓ Boliden (S7) 2023: 144 pages
#   → Downloading from: https://mb.cision.com/Main/16899/3057327/1209748.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S8/S8_2019_Annual_Report.pdf
#   → Downloaded: 4.4 MB
#   → Validating PDF...
#   → PDF has 140 pages
#   ✓ Success: 140 pages, 4.4 MB
#   ✓ Epiroc A (S8) 2019: 140 pages
#   → Downloading from: https://mb.cision.com/Main/16899/3304276/1385187.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S8/S8_2020_Annual_Report.pdf
#   → Downloaded: 20.9 MB
#   → Validating PDF...
#   → PDF has 192 pages
#   ✓ Success: 192 pages, 20.9 MB
#   ✓ Boliden (S7) 2024: 192 pages
#   → Downloading from: https://mb.cision.com/Main/16899/3517772/1543872.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S8/S8_2021_Annual_Report.pdf
#   → Downloading from: https://mb.cision.com/Public/997/3056299/97db413f283398d8.pdf
#   → Downloaded: 12.5 MB
#   → Validating PDF...
#   → PDF has 152 pages
#   ✓ Success: 152 pages, 12.5 MB
#   → Downloading from: https://mb.cision.com/Main/16899/3731614/1905213.pdf
#   ✓ Epiroc A (S8) 2020: 152 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S8/S8_2022_Annual_Report.pdf
#   🚫 HTTP 403 Forbidden - server may be blocking requests
#   ✗ Boliden (S7) 2019: HTTP 403
#   → Downloading from: https://mb.cision.com/Main/16899/3954175/2702722.pdf
#   → Downloaded: 12.5 MB
#   → Validating PDF...
#   → PDF has 152 pages
#   ✓ Success: 152 pages, 12.5 MB
#   → Downloading from: https://mb.cision.com/Main/16899/4132564/3374984.pdf
#   ✓ Epiroc A (S8) 2021: 152 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S8/S8_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S8/S8_2024_Annual_Report.pdf
#   → Downloaded: 16.0 MB
#   → Validating PDF...
#   → PDF has 164 pages
#   ✓ Success: 164 pages, 16.0 MB
#   ✓ Epiroc A (S8) 2022: 164 pages
#   → Downloading from: https://mb.cision.com/Main/87/3081202/1224326.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S9/S9_2019_Annual_Report.pdf
#   → Downloaded: 7.9 MB
#   → Validating PDF...
#   → PDF has 143 pages
#   ✓ Success: 143 pages, 7.9 MB
#   ✓ EQT (S9) 2019: 143 pages
#   → Downloading from: https://mb.cision.com/Main/87/3106749/1243974.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S9/S9_2020_Annual_Report.pdf
#   → Downloaded: 0.5 MB
#   → Validating PDF...
#   → PDF has 13 pages
#   ✗ Only 13 pages (min 50 required)
#   ✗ EQT (S9) 2020: Only 13 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/87/3533390/1554636.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S9/S9_2021_Annual_Report.pdf
#   → Downloaded: 10.5 MB
#   → Validating PDF...
#   → PDF has 180 pages
#   ✓ Success: 180 pages, 10.5 MB
#   ✓ EQT (S9) 2021: 180 pages
#   → Downloading from: https://mb.cision.com/Main/87/3743377/1953227.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S9/S9_2022_Annual_Report.pdf
#   → Downloaded: 9.8 MB
#   → Validating PDF...
#   → PDF has 176 pages
#   ✓ Success: 176 pages, 9.8 MB
#   ✓ Epiroc A (S8) 2023: 176 pages
#   → Downloading from: https://mb.cision.com/Main/87/3947084/2674429.pdf
#   → Downloaded: 10.6 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S9/S9_2023_Annual_Report.pdf
#   → PDF has 191 pages
#   ✓ Success: 191 pages, 10.6 MB
#   ✓ EQT (S9) 2022: 191 pages
#   → Downloading from: https://mb.cision.com/Main/87/4118218/3318218.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S9/S9_2024_Annual_Report.pdf
#   → Downloaded: 10.3 MB
#   → Validating PDF...
#   → PDF has 212 pages
#   ✓ Success: 212 pages, 10.3 MB
#   ✓ Epiroc A (S8) 2024: 212 pages
#   → Downloading from: https://mb.cision.com/Main/15448/3050872/1204724.pdf
#   → Downloaded: 8.5 MB
#   → Validating PDF...
#   → PDF has 171 pages
#   ✓ Success: 171 pages, 8.5 MB
#   → Downloading from: https://mb.cision.com/Main/15448/3300585/1382692.pdf
#   ✓ EQT (S9) 2023: 171 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S10/S10_2019_Annual_Report.pdf
#   → Downloaded: 8.2 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S10/S10_2020_Annual_Report.pdf
#   → PDF has 194 pages
#   ✓ Success: 194 pages, 8.2 MB
#   ✓ EQT (S9) 2024: 194 pages
#   → Downloading from: https://mb.cision.com/Main/15448/3519769/1545058.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S10/S10_2021_Annual_Report.pdf
#   → Downloaded: 4.8 MB
#   → Validating PDF...
#   → PDF has 220 pages
#   ✓ Success: 220 pages, 4.8 MB
#   ✓ Ericsson B (S10) 2019: 220 pages
#   → Downloading from: https://mb.cision.com/Main/15448/3729192/1896982.pdf
#   → Downloaded: 4.2 MB
#   → Validating PDF...
#   → PDF has 216 pages
#   ✓ Success: 216 pages, 4.2 MB
#   ✓ Ericsson B (S10) 2020: 216 pages
#   → Downloading from: https://mb.cision.com/Main/15448/3941077/2649306.pdf
#   → Downloaded: 4.6 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S10/S10_2022_Annual_Report.pdf
#   → PDF has 219 pages
#   ✓ Success: 219 pages, 4.6 MB
#   → Downloading from: https://mb.cision.com/Main/15448/4111350/3285958.pdf
#   ✓ Ericsson B (S10) 2021: 219 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S10/S10_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S10/S10_2024_Annual_Report.pdf
#   → Downloaded: 3.8 MB
#   → Validating PDF...
#   → PDF has 241 pages
#   ✓ Success: 241 pages, 3.8 MB
#   ✓ Ericsson B (S10) 2023: 241 pages
#   → Downloading from: https://mb.cision.com/Main/15798/3154642/1279575.pdf
#   → Downloaded: 4.3 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S11/S11_2019_Annual_Report.pdf
#   → PDF has 240 pages
#   ✓ Success: 240 pages, 4.3 MB
#   ✓ Ericsson B (S10) 2022: 240 pages
#   → Downloading from: https://mb.cision.com/Main/15798/3274602/1364026.pdf
#   → Downloaded: 8.9 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S11/S11_2020_Annual_Report.pdf
#   → PDF has 244 pages
#   ✓ Success: 244 pages, 8.9 MB
#   ✓ Ericsson B (S10) 2024: 244 pages
#   → Downloaded: 1.2 MB
#   → Validating PDF...
#   → Downloading from: https://mb.cision.com/Main/15798/3517187/1543095.pdf
#   → PDF has 27 pages
#   ✗ Only 27 pages (min 50 required)
#   ✗ Essity B (S11) 2019: Only 27 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/15798/3727262/1890017.pdf
#   → Downloaded: 1.2 MB
#   → Validating PDF...
#   → PDF has 26 pages
#   ✗ Only 26 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/15798/3937170/2634163.pdf
#   ✗ Essity B (S11) 2020: Only 26 pages (min 50 required)
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S11/S11_2022_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S11/S11_2021_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S11/S11_2023_Annual_Report.pdf
#   → Downloaded: 13.1 MB
#   → Validating PDF...
#   → PDF has 164 pages
#   ✓ Success: 164 pages, 13.1 MB
#   ✓ Essity B (S11) 2022: 164 pages
#   → URL doesn't end with .pdf, checking if it's an HTML page...
#   → Downloaded: 8.1 MB
#   → Validating PDF...
#   → PDF has 148 pages
#   ✓ Success: 148 pages, 8.1 MB
#   ✓ Essity B (S11) 2021: 148 pages
#   → Downloading from: https://mb.cision.com/Main/12069/3066661/1216435.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S12/S12_2019_Annual_Report.pdf
#   → Downloading from: https://mb.cision.com/Main/15798/4113057/3294193.pdf#page=7
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S11/S11_2024_Annual_Report.pdf
#   → Downloaded: 15.4 MB
#   → Validating PDF...
#   → PDF has 188 pages
#   ✓ Success: 188 pages, 15.4 MB
#   ✓ Essity B (S11) 2023: 188 pages
#   → Downloading from: https://www.evolution.com/wp-content/uploads/2025/04/Evolution-Annual-Report-2024.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S12/S12_2020_Annual_Report.pdf
#   → Downloaded: 9.3 MB
#   → Validating PDF...
#   → PDF has 116 pages
#   ✓ Success: 116 pages, 9.3 MB
#   ✓ Evolution (S12) 2019: 116 pages
#   → Downloading from: https://evolution-com-media.s3.eu-central-1.amazonaws.com/s3fs-public/1550307.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S12/S12_2021_Annual_Report.pdf
#   → Downloaded: 6.6 MB
#   → Validating PDF...
#   → PDF has 129 pages
#   ✓ Success: 129 pages, 6.6 MB
#   ✓ Evolution (S12) 2020: 129 pages
#   → Downloading from: https://mb.cision.com/Main/12069/3735605/1921487.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S12/S12_2022_Annual_Report.pdf
#   → Downloaded: 16.4 MB
#   → Validating PDF...
#   → PDF has 192 pages
#   ✓ Success: 192 pages, 16.4 MB
#   ✓ Essity B (S11) 2024: 192 pages
#   → Downloading from: https://www.evolution.com/wp-content/uploads/2023/03/Annual_Report_English_2022.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S12/S12_2023_Annual_Report.pdf
#   → Downloaded: 8.6 MB
#   → Validating PDF...
#   → PDF has 121 pages
#   ✓ Success: 121 pages, 8.6 MB
#   ✓ Evolution (S12) 2022: 121 pages
#   → Downloading from: https://www.evolution.com/wp-content/uploads/2024/04/Evolution_Annual_Report_2023.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S12/S12_2024_Annual_Report.pdf
#   → Downloaded: 8.6 MB
#   → Validating PDF...
#   → PDF has 121 pages
#   ✓ Success: 121 pages, 8.6 MB
#   ✓ Evolution (S12) 2023: 121 pages
#   → Downloading from: https://mb.cision.com/Main/769/3076990/1220978.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2019_Annual_Report.pdf
#   → Downloaded: 7.4 MB
#   → Validating PDF...
#   → PDF has 117 pages
#   ✓ Success: 117 pages, 7.4 MB
#   ✓ Evolution (S12) 2024: 117 pages
#   → Downloading from: https://hmgroup.com/wp-content/uploads/2025/03/HM-Group-Annual-and-sustainability-report-2024.pdf
#   → Downloaded: 3.8 MB
#   → Validating PDF...
#   → PDF has 88 pages
#   ✓ Success: 88 pages, 3.8 MB
#   ✓ Hennes & Mauritz B (S13) 2019: 88 pages
#   → Downloading from: https://mb.cision.com/Main/769/3536176/1556765.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2020_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2021_Annual_Report.pdf
#   → Downloaded: 8.3 MB
#   → Validating PDF...
#   → PDF has 87 pages
#   ✓ Success: 87 pages, 8.3 MB
#   → Downloading from: https://mb.cision.com/Main/769/3743344/1953371.pdf
#   ✓ Hennes & Mauritz B (S13) 2020: 87 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2022_Annual_Report.pdf
#   → Downloaded: 11.7 MB
#   → Validating PDF...
#   → PDF has 118 pages
#   ✓ Success: 118 pages, 11.7 MB
#   → Downloading from: https://mb.cision.com/Main/769/3952727/2698038.pdf
#   ✓ Hennes & Mauritz B (S13) 2021: 118 pages
#   → Downloaded: 4.3 MB
#   → Validating PDF...
#   → PDF has 152 pages
#   ✓ Success: 152 pages, 4.3 MB
#   ✓ Hennes & Mauritz B (S13) 2022: 152 pages
#   → Downloading from: https://mb.cision.com/Main/769/4124721/3347739.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S13/S13_2024_Annual_Report.pdf
#   → Downloaded: 12.8 MB
#   → Validating PDF...
#   → PDF has 148 pages
#   ✓ Success: 148 pages, 12.8 MB
#   ✓ Hennes & Mauritz B (S13) 2023: 148 pages
#   → Downloading from: https://mb.cision.com/Main/387/3080143/1223428.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S14/S14_2019_Annual_Report.pdf
#   → Downloaded: 3.8 MB
#   → Validating PDF...
#   → PDF has 88 pages
#   ✓ Success: 88 pages, 3.8 MB
#   → Downloading from: https://mb.cision.com/Main/387/3318474/1396045.pdf
#   ✓ Hexagon B (S14) 2019: 88 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S14/S14_2020_Annual_Report.pdf
#   → Downloaded: 9.2 MB
#   → Validating PDF...
#   → PDF has 87 pages
#   ✓ Success: 87 pages, 9.2 MB
#   → Downloading from: https://mb.cision.com/Main/387/3534740/1556124.pdf
#   ✓ Hennes & Mauritz B (S13) 2024: 87 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S14/S14_2021_Annual_Report.pdf
#   → Downloaded: 5.1 MB
#   → Validating PDF...
#   → PDF has 88 pages
#   ✓ Success: 88 pages, 5.1 MB
#   → Downloading from: https://mb.cision.com/Main/387/3743717/1957065.pdf
#   ✓ Hexagon B (S14) 2020: 88 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S14/S14_2022_Annual_Report.pdf
#   → Downloaded: 5.1 MB
#   → Validating PDF...
#   → PDF has 88 pages
#   ✓ Success: 88 pages, 5.1 MB
#   → Downloading from: https://mb.cision.com/Main/387/3952178/2698962.pdf
#   ✓ Hexagon B (S14) 2021: 88 pages
#   → Downloaded: 3.5 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S14/S14_2023_Annual_Report.pdf
#   → PDF has 88 pages
#   ✓ Success: 88 pages, 3.5 MB
#   ✓ Hexagon B (S14) 2022: 88 pages
#   → Downloading from: https://mb.cision.com/Main/387/4123663/3348237.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S14/S14_2024_Annual_Report.pdf
#   → Downloaded: 8.4 MB
#   → Validating PDF...
#   → PDF has 148 pages
#   ✓ Success: 148 pages, 8.4 MB
#   ✓ Hexagon B (S14) 2023: 148 pages
#   ✗ Industrivärden C (S15) 2019: No candidate URL for year
#   ✗ Industrivärden C (S15) 2020: No candidate URL for year
#   ✗ Industrivärden C (S15) 2021: No candidate URL for year
#   ✗ Industrivärden C (S15) 2022: No candidate URL for year
#   ✗ Industrivärden C (S15) 2023: No candidate URL for year
#   ✗ Industrivärden C (S15) 2024: No candidate URL for year
#   → Downloading from: https://mb.cision.com/Main/1084/2775825/1016251.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S16/S16_2019_Annual_Report.pdf
#   → Downloaded: 0.2 MB
#   → Validating PDF...
#   → PDF has 12 pages
#   ✗ Only 12 pages (min 50 required)
#   ✗ Investor B (S16) 2019: Only 12 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/1084/3316889/1394940.pdf
#   → Downloaded: 7.6 MB
#   → Validating PDF...
#   → PDF has 180 pages
#   ✓ Success: 180 pages, 7.6 MB
#   ✓ Hexagon B (S14) 2024: 180 pages
#   → Downloading from: https://mb.cision.com/Main/1084/3532369/1553846.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S16/S16_2020_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S16/S16_2021_Annual_Report.pdf
#   → Downloaded: 8.9 MB
#   → Validating PDF...
#   → PDF has 117 pages
#   ✓ Success: 117 pages, 8.9 MB
#   ✓ Evolution (S12) 2021: 117 pages
#   → Downloading from: https://mb.cision.com/Main/1084/3739428/1938982.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S16/S16_2022_Annual_Report.pdf
#   → Downloaded: 14.8 MB
#   → Validating PDF...
#   → PDF has 128 pages
#   ✓ Success: 128 pages, 14.8 MB
#   → Downloading from: https://mb.cision.com/Main/1084/3953149/2699359.pdf
#   ✓ Investor B (S16) 2020: 128 pages
#   → Downloaded: 3.7 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S16/S16_2023_Annual_Report.pdf
#   → PDF has 156 pages
#   ✓ Success: 156 pages, 3.7 MB
#   ✓ Investor B (S16) 2022: 156 pages
#   → Downloading from: https://mb.cision.com/Main/1084/4130452/3365717.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S16/S16_2024_Annual_Report.pdf
#   → Downloaded: 7.1 MB
#   → Validating PDF...
#   → PDF has 132 pages
#   ✓ Success: 132 pages, 7.1 MB
#   → Downloading from: https://network.s-z.se/app/uploads/sites/16/lifco-annual-report-2019.pdf
#   ✓ Investor B (S16) 2021: 132 pages
#   → Downloaded: 6.8 MB
#   → Validating PDF...
#   → PDF has 172 pages
#   ✓ Success: 172 pages, 6.8 MB
#   ✓ Investor B (S16) 2024: 172 pages
#   → Downloading from: https://network.s-z.se/app/uploads/sites/16/Lifco-annual-report-2017.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S17/S17_2019_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S17/S17_2020_Annual_Report.pdf
#   → Downloaded: 8.9 MB
#   → Validating PDF...
#   → PDF has 168 pages
#   ✓ Success: 168 pages, 8.9 MB
#   ✓ Investor B (S16) 2023: 168 pages
#   → Downloading from: https://network.s-z.se/app/uploads/sites/16/eng_lifco_annual_report_2021_webb.pdf
#   → Downloaded: 3.4 MB
#   → Validating PDF...
#   → PDF has 92 pages
#   ✓ Success: 92 pages, 3.4 MB
#   → Downloading from: https://network.s-z.se/app/uploads/sites/16/en_lifco_annualreport_2022.pdf
#   ✓ Lifco B (S17) 2020: 92 pages
#   → Downloaded: 2.9 MB
#   → Validating PDF...
#   → PDF has 104 pages
#   ✓ Success: 104 pages, 2.9 MB
#   ✓ Lifco B (S17) 2019: 104 pages
#   → Downloading from: https://network.s-z.se/app/uploads/sites/16/lifco_annual_report_2023.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S17/S17_2021_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S17/S17_2022_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S17/S17_2023_Annual_Report.pdf
#   → Downloaded: 4.5 MB
#   → Validating PDF...
#   → PDF has 120 pages
#   ✓ Success: 120 pages, 4.5 MB
#   ✓ Lifco B (S17) 2021: 120 pages
#   → Downloading from: https://network.s-z.se/app/uploads/sites/16/Lifco-annual-report-2024.pdf
#   → Downloaded: 5.7 MB
#   → Validating PDF...
#   → PDF has 156 pages
#   ✓ Success: 156 pages, 5.7 MB
#   ✓ Lifco B (S17) 2022: 156 pages
#   ✗ NIBE Industrier B (S18) 2019: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2020: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2021: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2022: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2023: No candidate URL for year
#   → Downloading from: https://storage.mfn.se/99ce48a8-9bf2-4af7-9d5d-3108ff73b8f5/se-nibe-ar-2024-w.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S17/S17_2024_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S18/S18_2024_Annual_Report.pdf
#   → Downloaded: 5.4 MB
#   → Validating PDF...
#   → PDF has 158 pages
#   ✓ Success: 158 pages, 5.4 MB
#   ✓ Lifco B (S17) 2023: 158 pages
#   → Downloading from: https://mb.cision.com/Main/434/3047655/1201947.pdf
#   → Downloaded: 17.5 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2019_Annual_Report.pdf
#   → PDF has 200 pages
#   ✓ Success: 200 pages, 17.5 MB
#   ✓ NIBE Industrier B (S18) 2024: 200 pages
#   → Downloading from: https://mb.cision.com/Main/434/3297563/1380411.pdf
#   → Downloaded: 8.9 MB
#   → Validating PDF...
#   → PDF has 154 pages
#   ✓ Success: 154 pages, 8.9 MB
#   ✓ Lifco B (S17) 2024: 154 pages
#   → Downloading from: https://mb.cision.com/Public/434/3517156/a676509631b85d17.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2021_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2020_Annual_Report.pdf
#   → Downloaded: 3.7 MB
#   → Validating PDF...
#   → PDF has 11 pages
#   ✗ Only 11 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Public/434/3725516/812c3dee2915cff3.pdf
#   ✗ Nordea Bank Abp (S19) 2021: Only 11 pages (min 50 required)
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2022_Annual_Report.pdf
#   → Downloaded: 7.8 MB
#   → Validating PDF...
#   → PDF has 296 pages
#   ✓ Success: 296 pages, 7.8 MB
#   → Downloading from: https://mb.cision.com/Main/434/3935418/2626561.pdf
#   ✓ Nordea Bank Abp (S19) 2019: 296 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2023_Annual_Report.pdf
#   → Downloaded: 8.7 MB
#   → Validating PDF...
#   → PDF has 364 pages
#   ✓ Success: 364 pages, 8.7 MB
#   → URL doesn't end with .pdf, checking if it's an HTML page...
#   ✓ Nordea Bank Abp (S19) 2022: 364 pages
#   → Downloaded: 9.2 MB
#   → Validating PDF...
# ignore '/Perms' verify failed
#   → PDF has 386 pages
#   ✓ Success: 386 pages, 9.2 MB
#   ✓ Nordea Bank Abp (S19) 2023: 386 pages
#   → Downloading from: https://mb.cision.com/Main/183/3052123/1205536.pdf
#   → Downloaded: 10.8 MB
#   → Validating PDF...
#   → PDF has 292 pages
#   ✓ Success: 292 pages, 10.8 MB
#   ✓ Nordea Bank Abp (S19) 2020: 292 pages
#   → Downloading from: https://mb.cision.com/Main/183/3300345/1382470.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S20/S20_2019_Annual_Report.pdf
#   → Downloaded: 0.0 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Public/183/3052123/97656ad42e7c7ce7.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S20/S20_2020_Annual_Report.pdf
#   → Downloading from: https://www.nordea.com/en/doc/annual-report-nordea-bank-abp-2024-0.pdf#page=5
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S20/S20_2019_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S19/S19_2024_Annual_Report.pdf
#   → Downloaded: 6.9 MB
#   → Validating PDF...
#   → PDF has 166 pages
#   ✓ Success: 166 pages, 6.9 MB
#   → Downloading from: https://mb.cision.com/Main/183/3518932/1544477.pdf
#   ✓ SAAB B (S20) 2020: 166 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S20/S20_2021_Annual_Report.pdf
#   → Downloaded: 7.5 MB
#   → Validating PDF...
#   → PDF has 152 pages
#   ✓ Success: 152 pages, 7.5 MB
#   ✓ SAAB B (S20) 2019: 152 pages
#   → Downloading from: https://mb.cision.com/Main/183/3729683/1899922.pdf
#   → Downloaded: 13.5 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S20/S20_2022_Annual_Report.pdf
#   → PDF has 384 pages
#   ✓ Success: 384 pages, 13.5 MB
#   ✓ Nordea Bank Abp (S19) 2024: 384 pages
#   → Downloading from: https://mb.cision.com/Main/183/3937793/2639666.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S20/S20_2023_Annual_Report.pdf
#   → Downloaded: 10.3 MB
#   → Validating PDF...
#   → PDF has 172 pages
#   ✓ Success: 172 pages, 10.3 MB
#   ✓ SAAB B (S20) 2022: 172 pages
#   → Downloading from: https://mb.cision.com/Main/183/4113322/3296554.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S20/S20_2024_Annual_Report.pdf
#   → Downloaded: 9.8 MB
#   → Validating PDF...
#   → PDF has 228 pages
#   ✓ Success: 228 pages, 9.8 MB
#   ✓ SAAB B (S20) 2024: 228 pages
#   → Downloading from: https://mb.cision.com/Main/208/3058294/1210382.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S21/S21_2019_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ Sandvik (S21) 2019: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/208/3308905/1388761.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S21/S21_2020_Annual_Report.pdf
#   → Downloaded: 12.9 MB
#   → Validating PDF...
#   → PDF has 180 pages
#   ✓ Success: 180 pages, 12.9 MB
#   ✓ SAAB B (S20) 2023: 180 pages
#   → Downloading from: https://mb.cision.com/Main/208/3523985/1547713.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S21/S21_2021_Annual_Report.pdf
#   → Downloaded: 12.1 MB
#   → Validating PDF...
#   → PDF has 168 pages
#   ✓ Success: 168 pages, 12.1 MB
#   ✓ SAAB B (S20) 2021: 168 pages
#   → Downloading from: https://mb.cision.com/Main/208/3731461/1904641.pdf
#   → Downloaded: 7.9 MB
#   → Validating PDF...
#   → PDF has 148 pages
#   ✓ Success: 148 pages, 7.9 MB
#   ✓ Sandvik (S21) 2020: 148 pages
#   → Downloading from: https://mb.cision.com/Main/208/3943621/2664685.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S21/S21_2023_Annual_Report.pdf
#   → Downloaded: 6.6 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S21/S21_2022_Annual_Report.pdf
#   → PDF has 160 pages
#   ✓ Success: 160 pages, 6.6 MB
#   → Downloading from: https://mb.cision.com/Main/208/4114009/3308864.pdf
#   ✓ Sandvik (S21) 2021: 160 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S21/S21_2024_Annual_Report.pdf
#   → Downloaded: 9.7 MB
#   → Validating PDF...
#   → PDF has 168 pages
#   ✓ Success: 168 pages, 9.7 MB
#   ✓ Sandvik (S21) 2023: 168 pages
#   → Downloading from: https://mb.cision.com/Main/600/3053862/1206818.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S22/S22_2019_Annual_Report.pdf
#   → Downloaded: 9.8 MB
#   → Validating PDF...
#   → PDF has 160 pages
#   ✓ Success: 160 pages, 9.8 MB
#   ✓ Sandvik (S21) 2022: 160 pages
#   → Downloading from: https://mb.cision.com/Main/600/3308556/1388439.pdf
#   → Downloaded: 8.1 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S22/S22_2020_Annual_Report.pdf
#   → PDF has 160 pages
#   ✓ Success: 160 pages, 8.1 MB
#   ✓ Sandvik (S21) 2024: 160 pages
#   → Downloading from: https://mb.cision.com/Main/600/3520131/1545335.pdf
#   → Downloaded: 14.0 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S22/S22_2021_Annual_Report.pdf
#   → PDF has 168 pages
#   ✓ Success: 168 pages, 14.0 MB
#   ✓ SCA B (S22) 2019: 168 pages
#   → Downloading from: https://mb.cision.com/Main/600/3728359/1894286.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ SCA B (S22) 2021: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/600/3938079/2637715.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S22/S22_2022_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S22/S22_2023_Annual_Report.pdf
#   → Downloaded: 12.3 MB
#   → Validating PDF...
#   → PDF has 180 pages
#   ✓ Success: 180 pages, 12.3 MB
#   ✓ SCA B (S22) 2020: 180 pages
#   → Downloading from: https://www.sca.com/siteassets/investors/reports-and-presentations/annual-reports/2024/sca_ar24_eng.pdf
#   → Downloaded: 11.8 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S22/S22_2024_Annual_Report.pdf
#   → PDF has 196 pages
#   ✓ Success: 196 pages, 11.8 MB
#   ✓ SCA B (S22) 2023: 196 pages
#   → Downloading from: https://mb.cision.com/Main/4324/3222287/1323639.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2019_Annual_Report.pdf
#   → Downloaded: 0.0 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/4324/3298906/1381441.pdf
#   ✗ SEB A (S23) 2019: Only 1 pages (min 50 required)
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2020_Annual_Report.pdf
#   → Downloaded: 0.0 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ SEB A (S23) 2020: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/4324/3516765/1542756.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2021_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   ✗ SEB A (S23) 2021: Only 2 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/4324/3724878/1881092.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2022_Annual_Report.pdf
#   → Downloaded: 15.8 MB
#   → Validating PDF...
#   → PDF has 202 pages
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   ✓ Success: 202 pages, 15.8 MB
#   → Downloading from: https://mb.cision.com/Main/4324/3936474/2631963.pdf
#   ✓ SCA B (S22) 2024: 202 pages
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   ✗ SEB A (S23) 2022: Only 2 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/4324/4117258/3314101.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2023_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S23/S23_2024_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   ✗ SEB A (S23) 2023: Only 2 pages (min 50 required)
#   ✗ Skanska B (S24) 2019: No candidate URL for year
#   → Downloading from: https://mb.cision.com/Main/95/3069349/1218328.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S24/S24_2020_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 3 pages
#   ✗ Only 3 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/95/3497789/1528995.pdf
#   ✗ Skanska B (S24) 2020: Only 3 pages (min 50 required)
#   → Downloaded: 9.5 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S24/S24_2021_Annual_Report.pdf
#   → PDF has 307 pages
#   ✓ Success: 307 pages, 9.5 MB
#   ✓ SEB A (S23) 2024: 307 pages
#   → Downloading from: https://mb.cision.com/Main/95/3729491/1898361.pdf
#   → Downloaded: 11.5 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S24/S24_2022_Annual_Report.pdf
#   → PDF has 192 pages
#   ✓ Success: 192 pages, 11.5 MB
#   ✓ SCA B (S22) 2022: 192 pages
#   → Downloading from: https://mb.cision.com/Main/95/3941541/2651266.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S24/S24_2023_Annual_Report.pdf
#   → Downloaded: 15.8 MB
#   → Validating PDF...
#   → PDF has 224 pages
#   ✓ Success: 224 pages, 15.8 MB
#   ✓ Skanska B (S24) 2022: 224 pages
#   → Downloading from: https://group.skanska.com/49490b/siteassets/investors/reports-publications/annual-reports/2024/annual-and-sustainability-report-2024.pdf
#   → Downloaded: 6.2 MB
#   → Validating PDF...
#   → PDF has 30 pages
#   ✗ Only 30 pages (min 50 required)
#   ✗ Skanska B (S24) 2021: Only 30 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/637/3052162/1205531.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S25/S25_2019_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S24/S24_2024_Annual_Report.pdf
#   → Downloaded: 0.3 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   ✗ SKF B (S25) 2019: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/637/3299288/1381830.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S25/S25_2020_Annual_Report.pdf
#   → Downloaded: 19.3 MB
#   → Validating PDF...
#   → PDF has 226 pages
#   ✓ Success: 226 pages, 19.3 MB
#   ✓ Skanska B (S24) 2023: 226 pages
#   → Downloading from: https://mb.cision.com/Main/637/3517209/1543197.pdf
#   → Downloaded: 14.5 MB
#   → Validating PDF...
#   → PDF has 232 pages
#   ✓ Success: 232 pages, 14.5 MB
#   → Downloading from: https://mb.cision.com/Main/637/3725597/1883909.pdf
#   ✓ Skanska B (S24) 2024: 232 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S25/S25_2021_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S25/S25_2022_Annual_Report.pdf
#   → Downloaded: 7.4 MB
#   → Validating PDF...
#   → PDF has 162 pages
#   ✓ Success: 162 pages, 7.4 MB
#   ✓ SKF B (S25) 2020: 162 pages
#   → Downloading from: https://mb.cision.com/Main/637/3939698/2642356.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S25/S25_2023_Annual_Report.pdf
#   → Downloaded: 8.8 MB
#   → Validating PDF...
#   → PDF has 162 pages
#   ✓ Success: 162 pages, 8.8 MB
#   ✓ SKF B (S25) 2021: 162 pages
#   → Downloading from: https://mb.cision.com/Main/637/4115866/3306976.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S25/S25_2024_Annual_Report.pdf
#   → Downloaded: 9.8 MB
#   → Validating PDF...
#   → PDF has 150 pages
#   ✓ Success: 150 pages, 9.8 MB
#   ✓ SKF B (S25) 2022: 150 pages
#   → Downloading from: https://mb.cision.com/Main/3555/3035159/1193715.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2019_Annual_Report.pdf
#   → Downloaded: 2.5 MB
#   → Validating PDF...
#   → PDF has 260 pages
#   ✓ Success: 260 pages, 2.5 MB
#   ✓ Sv. Handelsbanken A (S26) 2019: 260 pages
#   → Downloading from: https://mb.cision.com/Main/3555/3294359/1377796.pdf
#   → Downloaded: 14.4 MB
#   → Validating PDF...
#   → PDF has 160 pages
#   ✓ Success: 160 pages, 14.4 MB
#   ✓ SKF B (S25) 2023: 160 pages
#   → Downloading from: https://mb.cision.com/Main/3555/3519940/1545190.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2020_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2021_Annual_Report.pdf
#   → Downloaded: 6.6 MB
#   → Validating PDF...
#   → PDF has 175 pages
#   ✓ Success: 175 pages, 6.6 MB
#   ✓ SKF B (S25) 2024: 175 pages
#   → Downloading from: https://mb.cision.com/Main/3555/3723067/1874784.pdf
#   → Downloaded: 5.2 MB
#   → Validating PDF...
#   → PDF has 272 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2022_Annual_Report.pdf
#   ✓ Success: 272 pages, 5.2 MB
#   ✓ Sv. Handelsbanken A (S26) 2020: 272 pages
#   → Downloading from: https://mb.cision.com/Main/3555/3934283/2623393.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2023_Annual_Report.pdf
#   → Downloaded: 5.7 MB
#   → Validating PDF...
#   → PDF has 284 pages
#   ✓ Success: 284 pages, 5.7 MB
#   ✓ Sv. Handelsbanken A (S26) 2021: 284 pages
#   → Downloading from: https://mb.cision.com/Main/3555/4111826/3288310.pdf
#   → Downloaded: 5.1 MB
#   → Validating PDF...
#   → PDF has 272 pages
#   ✓ Success: 272 pages, 5.1 MB
#   ✓ Sv. Handelsbanken A (S26) 2022: 272 pages
#   → Downloading from: https://mb.cision.com/Main/67/3039111/1196760.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S26/S26_2024_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S27/S27_2019_Annual_Report.pdf
#   → Downloaded: 4.3 MB
#   → Validating PDF...
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 312 pages
#   ✓ Success: 312 pages, 4.3 MB
#   ✓ Sv. Handelsbanken A (S26) 2023: 312 pages
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/67/3365325/1430768.pdf
#   ✗ Swedbank A (S27) 2019: Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/67/3512868/1539649.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S27/S27_2020_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S27/S27_2021_Annual_Report.pdf
#   → Downloaded: 6.7 MB
#   → Validating PDF...
#   → Downloaded: 0.2 MB
#   → Validating PDF...
#   → PDF has 2 pages
#   ✗ Only 2 pages (min 50 required)
#   ✗ Swedbank A (S27) 2020: Only 2 pages (min 50 required)  → Downloading from: https://mb.cision.com/Main/67/3722323/1870905.pdf
#
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S27/S27_2022_Annual_Report.pdf
#   → PDF has 388 pages
#   ✓ Success: 388 pages, 6.7 MB
#   ✓ Sv. Handelsbanken A (S26) 2024: 388 pages
#   → Downloading from: https://mb.cision.com/Main/67/3978851/2794734.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S27/S27_2023_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/67/4111985/3289763.pdf
#   ✗ Swedbank A (S27) 2023: Only 1 pages (min 50 required)
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S27/S27_2024_Annual_Report.pdf
#   → Downloaded: 5.0 MB
#   → Validating PDF...
#   → PDF has 256 pages
#   ✓ Success: 256 pages, 5.0 MB
#   ✓ Swedbank A (S27) 2021: 256 pages
#   → Downloading from: https://mb.cision.com/Main/3372/3068881/1218057.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S28/S28_2019_Annual_Report.pdf
#   → Downloaded: 7.8 MB
#   → Validating PDF...
#   → PDF has 386 pages
#   ✓ Success: 386 pages, 7.8 MB
#   → Downloading from: https://mb.cision.com/Main/3372/3313796/1392365.pdf
#   ✓ Swedbank A (S27) 2024: 386 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S28/S28_2020_Annual_Report.pdf
#   → Downloaded: 4.0 MB
#   → Validating PDF...
#   → PDF has 136 pages
#   ✓ Success: 136 pages, 4.0 MB
#   ✓ Tele2 B (S28) 2020: 136 pages
#   → Downloading from: https://mb.cision.com/Main/3372/3535246/1555943.pdf
#   → Downloaded: 6.5 MB
#   → Validating PDF...
#   → PDF has 260 pages
#   ✓ Success: 260 pages, 6.5 MB
#   ✓ Swedbank A (S27) 2022: 260 pages
#   → Downloading from: https://mb.cision.com/Main/3372/3745841/1962077.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S28/S28_2021_Annual_Report.pdf
#   → Downloaded: 8.1 MB
#   → Validating PDF...
#   → PDF has 94 pages
#   ✓ Success: 94 pages, 8.1 MB
#   ✓ Tele2 B (S28) 2019: 94 pages
#   → Downloading from: https://mb.cision.com/Main/3372/3954298/2703759.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S28/S28_2022_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S28/S28_2023_Annual_Report.pdf
#   → Downloaded: 9.9 MB
#   → Validating PDF...
#   → PDF has 151 pages
#   ✓ Success: 151 pages, 9.9 MB
#   ✓ Tele2 B (S28) 2021: 151 pages
#   → Downloading from: https://mb.cision.com/Main/3372/4129651/3363921.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S28/S28_2024_Annual_Report.pdf
#   → Downloaded: 8.3 MB
#   → Validating PDF...
#   → Downloaded: 10.2 MB
#   → Validating PDF...
#   → PDF has 211 pages
#   ✓ Success: 211 pages, 8.3 MB
#   → Downloading from: https://mb.cision.com/Main/40/3057357/1209600.pdf
#   ✓ Tele2 B (S28) 2024: 211 pages
#   → PDF has 162 pages
#   ✓ Success: 162 pages, 10.2 MB
#   → Downloading from: https://mb.cision.com/Main/40/3229596/1329189.pdf
#   ✓ Tele2 B (S28) 2022: 162 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S29/S29_2020_Annual_Report.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 4 pages
#   ✗ Only 4 pages (min 50 required)
#   ✗ Telia Company (S29) 2020: Only 4 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/40/3522382/1546730.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S29/S29_2019_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S29/S29_2021_Annual_Report.pdf
#   → Downloaded: 7.0 MB
#   → Validating PDF...
#   → PDF has 241 pages
#   ✓ Success: 241 pages, 7.0 MB
#   ✓ Telia Company (S29) 2019: 241 pages
#   → Downloading from: https://mb.cision.com/Main/40/3754341/1996100.pdf
#   → Downloaded: 12.8 MB
#   → Validating PDF...
#   → PDF has 164 pages
#   ✓ Success: 164 pages, 12.8 MB
#   → Downloading from: https://mb.cision.com/Main/40/3947189/2674950.pdf
#   ✓ Tele2 B (S28) 2023: 164 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S29/S29_2022_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S29/S29_2023_Annual_Report.pdf
#   → Downloaded: 13.9 MB
#   → Validating PDF...
#   → PDF has 266 pages
#   ✓ Success: 266 pages, 13.9 MB
#   → Downloading from: https://mb.cision.com/Main/40/4089761/3199587.pdf
#   ✓ Telia Company (S29) 2021: 266 pages
#   → Downloaded: 8.1 MB
#   → Validating PDF...
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S29/S29_2024_Annual_Report.pdf
#   → PDF has 263 pages
#   ✓ Success: 263 pages, 8.1 MB
#   ✓ Telia Company (S29) 2022: 263 pages
#   → Downloading from: https://mb.cision.com/Main/39/3045690/1200842.pdf
#   → Downloaded: 0.1 MB
#   → Validating PDF...
#   → PDF has 1 pages
#   ✗ Only 1 pages (min 50 required)
#   → Downloading from: https://mb.cision.com/Main/39/3297011/1379923.pdf
#   ✗ Telia Company (S29) 2024: Only 1 pages (min 50 required)
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S30/S30_2019_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S30/S30_2020_Annual_Report.pdf
#   → Downloaded: 6.5 MB
#   → Validating PDF...
#   → PDF has 271 pages
#   ✓ Success: 271 pages, 6.5 MB
#   ✓ Telia Company (S29) 2023: 271 pages
#   → Downloading from: https://mb.cision.com/Main/39/3513638/1540980.pdf
#   → Downloaded: 10.7 MB
#   → Validating PDF...
#   → PDF has 230 pages
#   ✓ Success: 230 pages, 10.7 MB
#   → Downloading from: https://mb.cision.com/Main/39/3724997/1882138.pdf
#   ✓ Volvo B (S30) 2019: 230 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S30/S30_2021_Annual_Report.pdf
#   → Downloaded: 10.7 MB
#   → Validating PDF...
#   → PDF has 210 pages
#   ✓ Success: 210 pages, 10.7 MB
#   → Downloading from: https://mb.cision.com/Main/39/3938374/2638725.pdf
#   ✓ Volvo B (S30) 2020: 210 pages
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S30/S30_2022_Annual_Report.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S30/S30_2023_Annual_Report.pdf
#   → Downloaded: 10.8 MB
#   → Validating PDF...
#   → PDF has 218 pages
#   ✓ Success: 218 pages, 10.8 MB
#   ✓ Volvo B (S30) 2021: 218 pages
#   → Downloading from: https://mb.cision.com/Main/39/4112014/3290343.pdf
#   → Saving to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/companies/S30/S30_2024_Annual_Report.pdf
#   → Downloaded: 13.0 MB
#   → Validating PDF...
#   → Downloaded: 14.4 MB
#   → Validating PDF...
#   → PDF has 226 pages
#   ✓ Success: 226 pages, 13.0 MB
#   ✓ Volvo B (S30) 2022: 226 pages
#   → PDF has 232 pages
#   ✓ Success: 232 pages, 14.4 MB
#   ✓ Volvo B (S30) 2023: 232 pages
#   → Downloaded: 10.6 MB
#   → Validating PDF...
#   → PDF has 220 pages
#   ✓ Success: 220 pages, 10.6 MB
#   ✓ Volvo B (S30) 2024: 220 pages
#
# 📊 Download summary saved to: /Users/jakobjohannesson/Documents/github_repos/aspiratio/download_summary_from_candidates.json
#   cid    company  year   status  \
# 0  S1    ABB Ltd  2019   failed
# 1  S1    ABB Ltd  2021   failed
# 2  S1    ABB Ltd  2020   failed
# 3  S1    ABB Ltd  2022   failed
# 4  S1    ABB Ltd  2023   failed
# 5  S1    ABB Ltd  2024   failed
# 6  S2  Addtech B  2019  success
# 7  S2  Addtech B  2020  success
# 8  S2  Addtech B  2021  success
# 9  S2  Addtech B  2022  success
#
#                                                  url  \
# 0  https://mb.cision.com/Main/417/3045869/1201088...
# 1  https://mb.cision.com/Main/417/3516666/1542750...
# 2  https://mb.cision.com/Main/417/3296284/1379492...
# 3  https://mb.cision.com/Main/417/3725044/1882197...
# 4  https://global.abb/content/dam/abb/global/grou...
# 5  https://storage.mfn.se/c/aHR0cHM6Ly9lcXMtY29ja...
# 6  https://www.addtech.com/fileadmin/user_upload/...
# 7  https://www.addtech.com/fileadmin/user_upload/...
# 8  https://www.addtech.com/fileadmin/user_upload/...
# 9  https://www.addtech.com/fileadmin/user_upload/...
#
#                                          source_page  \
# 0              https://global.abb/group/en/investors
# 1              https://global.abb/group/en/investors
# 2              https://global.abb/group/en/investors
# 3              https://global.abb/group/en/investors
# 4              https://global.abb/group/en/investors
# 5              https://global.abb/group/en/investors
# 6  https://www.addtech.com/investors-and-media/an...
# 7  https://www.addtech.com/investors-and-media/an...
# 8  https://www.addtech.com/investors-and-media/an...
# 9  https://www.addtech.com/investors-and-media/an...
#
#                              error  pages    size_mb title  \
# 0   Only 1 pages (min 50 required)      0   0.000000   NaN
# 1   Only 1 pages (min 50 required)      0   0.000000   NaN
# 2   Only 1 pages (min 50 required)      0   0.000000   NaN
# 3   Only 1 pages (min 50 required)      0   0.000000   NaN
# 4  Only 23 pages (min 50 required)      0   0.000000   NaN
# 5   Only 2 pages (min 50 required)      0   0.000000   NaN
# 6                                      61  11.168268   pdf
# 7                                      74  13.500546   pdf
# 8                                      74  12.474593   pdf
# 9                                      80  14.207037   pdf
#
#                                          output_path
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  /Users/jakobjohannesson/Documents/github_repos...
# 7  /Users/jakobjohannesson/Documents/github_repos...
# 8  /Users/jakobjohannesson/Documents/github_repos...
# 9  /Users/jakobjohannesson/Documents/github_repos...

# %%
# Summarize download outcomes
successes = results_df[results_df['status'] == 'success']
failures = results_df[results_df['status'] == 'failed']

print('Download Summary')
print('=' * 50)
print(f"✓ Successful downloads: {len(successes)}")
print(f"✗ Failed downloads: {len(failures)}")
print(f"Total attempted: {len(results_df)}")

if len(successes) > 0:
    print(f"\nSuccessful downloads:")
    for _, row in successes.iterrows():
        pages = row.get('pages', '?')
        print(f"  ✓ {row['company']} ({row['cid']}) {row['year']}: {pages} pages")

if len(failures) > 0:
    print(f"\nFailed downloads (by error type):")
    error_counts = failures.groupby('error').size().sort_values(ascending=False)
    for error, count in error_counts.items():
        print(f"  • {error}: {count}")
    
    print(f"\nFailed details:")
    for _, row in failures.iterrows():
        print(f"  ✗ {row['company']} ({row['cid']}) {row['year']}: {row['error']}")
# Out:
# Download Summary
# ==================================================
# ✓ Successful downloads: 135
# ✗ Failed downloads: 45
# Total attempted: 180
#
# Successful downloads:
#   ✓ Addtech B (S2) 2019: 61 pages
#   ✓ Addtech B (S2) 2020: 74 pages
#   ✓ Addtech B (S2) 2021: 74 pages
#   ✓ Addtech B (S2) 2022: 80 pages
#   ✓ Addtech B (S2) 2024: 152 pages
#   ✓ Addtech B (S2) 2023: 155 pages
#   ✓ Alfa Laval (S3) 2019: 152 pages
#   ✓ Alfa Laval (S3) 2020: 160 pages
#   ✓ Alfa Laval (S3) 2021: 194 pages
#   ✓ Alfa Laval (S3) 2023: 192 pages
#   ✓ Alfa Laval (S3) 2024: 81 pages
#   ✓ Alfa Laval (S3) 2022: 200 pages
#   ✓ ASSA ABLOY B (S4) 2019: 108 pages
#   ✓ ASSA ABLOY B (S4) 2020: 112 pages
#   ✓ ASSA ABLOY B (S4) 2022: 116 pages
#   ✓ ASSA ABLOY B (S4) 2021: 116 pages
#   ✓ ASSA ABLOY B (S4) 2023: 116 pages
#   ✓ ASSA ABLOY B (S4) 2024: 164 pages
#   ✓ Atlas Copco A (S6) 2020: 144 pages
#   ✓ Atlas Copco A (S6) 2019: 150 pages
#   ✓ Atlas Copco A (S6) 2021: 148 pages
#   ✓ Atlas Copco A (S6) 2022: 152 pages
#   ✓ Atlas Copco A (S6) 2024: 169 pages
#   ✓ Atlas Copco A (S6) 2023: 154 pages
#   ✓ Boliden (S7) 2020: 124 pages
#   ✓ Boliden (S7) 2021: 128 pages
#   ✓ Boliden (S7) 2022: 136 pages
#   ✓ Boliden (S7) 2023: 144 pages
#   ✓ Epiroc A (S8) 2019: 140 pages
#   ✓ Boliden (S7) 2024: 192 pages
#   ✓ Epiroc A (S8) 2020: 152 pages
#   ✓ Epiroc A (S8) 2021: 152 pages
#   ✓ Epiroc A (S8) 2022: 164 pages
#   ✓ EQT (S9) 2019: 143 pages
#   ✓ EQT (S9) 2021: 180 pages
#   ✓ Epiroc A (S8) 2023: 176 pages
#   ✓ EQT (S9) 2022: 191 pages
#   ✓ Epiroc A (S8) 2024: 212 pages
#   ✓ EQT (S9) 2023: 171 pages
#   ✓ EQT (S9) 2024: 194 pages
#   ✓ Ericsson B (S10) 2019: 220 pages
#   ✓ Ericsson B (S10) 2020: 216 pages
#   ✓ Ericsson B (S10) 2021: 219 pages
#   ✓ Ericsson B (S10) 2023: 241 pages
#   ✓ Ericsson B (S10) 2022: 240 pages
#   ✓ Ericsson B (S10) 2024: 244 pages
#   ✓ Essity B (S11) 2022: 164 pages
#   ✓ Essity B (S11) 2021: 148 pages
#   ✓ Essity B (S11) 2023: 188 pages
#   ✓ Evolution (S12) 2019: 116 pages
#   ✓ Evolution (S12) 2020: 129 pages
#   ✓ Essity B (S11) 2024: 192 pages
#   ✓ Evolution (S12) 2022: 121 pages
#   ✓ Evolution (S12) 2023: 121 pages
#   ✓ Evolution (S12) 2024: 117 pages
#   ✓ Hennes & Mauritz B (S13) 2019: 88 pages
#   ✓ Hennes & Mauritz B (S13) 2020: 87 pages
#   ✓ Hennes & Mauritz B (S13) 2021: 118 pages
#   ✓ Hennes & Mauritz B (S13) 2022: 152 pages
#   ✓ Hennes & Mauritz B (S13) 2023: 148 pages
#   ✓ Hexagon B (S14) 2019: 88 pages
#   ✓ Hennes & Mauritz B (S13) 2024: 87 pages
#   ✓ Hexagon B (S14) 2020: 88 pages
#   ✓ Hexagon B (S14) 2021: 88 pages
#   ✓ Hexagon B (S14) 2022: 88 pages
#   ✓ Hexagon B (S14) 2023: 148 pages
#   ✓ Hexagon B (S14) 2024: 180 pages
#   ✓ Evolution (S12) 2021: 117 pages
#   ✓ Investor B (S16) 2020: 128 pages
#   ✓ Investor B (S16) 2022: 156 pages
#   ✓ Investor B (S16) 2021: 132 pages
#   ✓ Investor B (S16) 2024: 172 pages
#   ✓ Investor B (S16) 2023: 168 pages
#   ✓ Lifco B (S17) 2020: 92 pages
#   ✓ Lifco B (S17) 2019: 104 pages
#   ✓ Lifco B (S17) 2021: 120 pages
#   ✓ Lifco B (S17) 2022: 156 pages
#   ✓ Lifco B (S17) 2023: 158 pages
#   ✓ NIBE Industrier B (S18) 2024: 200 pages
#   ✓ Lifco B (S17) 2024: 154 pages
#   ✓ Nordea Bank Abp (S19) 2019: 296 pages
#   ✓ Nordea Bank Abp (S19) 2022: 364 pages
#   ✓ Nordea Bank Abp (S19) 2023: 386 pages
#   ✓ Nordea Bank Abp (S19) 2020: 292 pages
#   ✓ SAAB B (S20) 2020: 166 pages
#   ✓ SAAB B (S20) 2019: 152 pages
#   ✓ Nordea Bank Abp (S19) 2024: 384 pages
#   ✓ SAAB B (S20) 2022: 172 pages
#   ✓ SAAB B (S20) 2024: 228 pages
#   ✓ SAAB B (S20) 2023: 180 pages
#   ✓ SAAB B (S20) 2021: 168 pages
#   ✓ Sandvik (S21) 2020: 148 pages
#   ✓ Sandvik (S21) 2021: 160 pages
#   ✓ Sandvik (S21) 2023: 168 pages
#   ✓ Sandvik (S21) 2022: 160 pages
#   ✓ Sandvik (S21) 2024: 160 pages
#   ✓ SCA B (S22) 2019: 168 pages
#   ✓ SCA B (S22) 2020: 180 pages
#   ✓ SCA B (S22) 2023: 196 pages
#   ✓ SCA B (S22) 2024: 202 pages
#   ✓ SEB A (S23) 2024: 307 pages
#   ✓ SCA B (S22) 2022: 192 pages
#   ✓ Skanska B (S24) 2022: 224 pages
#   ✓ Skanska B (S24) 2023: 226 pages
#   ✓ Skanska B (S24) 2024: 232 pages
#   ✓ SKF B (S25) 2020: 162 pages
#   ✓ SKF B (S25) 2021: 162 pages
#   ✓ SKF B (S25) 2022: 150 pages
#   ✓ Sv. Handelsbanken A (S26) 2019: 260 pages
#   ✓ SKF B (S25) 2023: 160 pages
#   ✓ SKF B (S25) 2024: 175 pages
#   ✓ Sv. Handelsbanken A (S26) 2020: 272 pages
#   ✓ Sv. Handelsbanken A (S26) 2021: 284 pages
#   ✓ Sv. Handelsbanken A (S26) 2022: 272 pages
#   ✓ Sv. Handelsbanken A (S26) 2023: 312 pages
#   ✓ Sv. Handelsbanken A (S26) 2024: 388 pages
#   ✓ Swedbank A (S27) 2021: 256 pages
#   ✓ Swedbank A (S27) 2024: 386 pages
#   ✓ Tele2 B (S28) 2020: 136 pages
#   ✓ Swedbank A (S27) 2022: 260 pages
#   ✓ Tele2 B (S28) 2019: 94 pages
#   ✓ Tele2 B (S28) 2021: 151 pages
#   ✓ Tele2 B (S28) 2024: 211 pages
#   ✓ Tele2 B (S28) 2022: 162 pages
#   ✓ Telia Company (S29) 2019: 241 pages
#   ✓ Tele2 B (S28) 2023: 164 pages
#   ✓ Telia Company (S29) 2021: 266 pages
#   ✓ Telia Company (S29) 2022: 263 pages
#   ✓ Telia Company (S29) 2023: 271 pages
#   ✓ Volvo B (S30) 2019: 230 pages
#   ✓ Volvo B (S30) 2020: 210 pages
#   ✓ Volvo B (S30) 2021: 218 pages
#   ✓ Volvo B (S30) 2022: 226 pages
#   ✓ Volvo B (S30) 2023: 232 pages
#   ✓ Volvo B (S30) 2024: 220 pages
#
# Failed downloads (by error type):
#   • No candidate URL for year: 18
#   • Only 1 pages (min 50 required): 12
#   • Only 2 pages (min 50 required): 5
#   • HTTP 403: 1
#   • Only 11 pages (min 50 required): 1
#   • Only 12 pages (min 50 required): 1
#   • Only 13 pages (min 50 required): 1
#   • Only 23 pages (min 50 required): 1
#   • Only 26 pages (min 50 required): 1
#   • Only 27 pages (min 50 required): 1
#   • Only 3 pages (min 50 required): 1
#   • Only 30 pages (min 50 required): 1
#   • Only 4 pages (min 50 required): 1
#
# Failed details:
#   ✗ ABB Ltd (S1) 2019: Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2021: Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2020: Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2022: Only 1 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2023: Only 23 pages (min 50 required)
#   ✗ ABB Ltd (S1) 2024: Only 2 pages (min 50 required)
#   ✗ AstraZeneca (S5) 2019: No candidate URL for year
#   ✗ AstraZeneca (S5) 2020: No candidate URL for year
#   ✗ AstraZeneca (S5) 2021: No candidate URL for year
#   ✗ AstraZeneca (S5) 2022: No candidate URL for year
#   ✗ AstraZeneca (S5) 2023: No candidate URL for year
#   ✗ AstraZeneca (S5) 2024: No candidate URL for year
#   ✗ Boliden (S7) 2019: HTTP 403
#   ✗ EQT (S9) 2020: Only 13 pages (min 50 required)
#   ✗ Essity B (S11) 2019: Only 27 pages (min 50 required)
#   ✗ Essity B (S11) 2020: Only 26 pages (min 50 required)
#   ✗ Industrivärden C (S15) 2019: No candidate URL for year
#   ✗ Industrivärden C (S15) 2020: No candidate URL for year
#   ✗ Industrivärden C (S15) 2021: No candidate URL for year
#   ✗ Industrivärden C (S15) 2022: No candidate URL for year
#   ✗ Industrivärden C (S15) 2023: No candidate URL for year
#   ✗ Industrivärden C (S15) 2024: No candidate URL for year
#   ✗ Investor B (S16) 2019: Only 12 pages (min 50 required)
#   ✗ NIBE Industrier B (S18) 2019: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2020: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2021: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2022: No candidate URL for year
#   ✗ NIBE Industrier B (S18) 2023: No candidate URL for year
#   ✗ Nordea Bank Abp (S19) 2021: Only 11 pages (min 50 required)
#   ✗ Sandvik (S21) 2019: Only 1 pages (min 50 required)
#   ✗ SCA B (S22) 2021: Only 1 pages (min 50 required)
#   ✗ SEB A (S23) 2019: Only 1 pages (min 50 required)
#   ✗ SEB A (S23) 2020: Only 1 pages (min 50 required)
#   ✗ SEB A (S23) 2021: Only 2 pages (min 50 required)
#   ✗ SEB A (S23) 2022: Only 2 pages (min 50 required)
#   ✗ SEB A (S23) 2023: Only 2 pages (min 50 required)
#   ✗ Skanska B (S24) 2019: No candidate URL for year
#   ✗ Skanska B (S24) 2020: Only 3 pages (min 50 required)
#   ✗ Skanska B (S24) 2021: Only 30 pages (min 50 required)
#   ✗ SKF B (S25) 2019: Only 1 pages (min 50 required)
#   ✗ Swedbank A (S27) 2019: Only 1 pages (min 50 required)
#   ✗ Swedbank A (S27) 2020: Only 2 pages (min 50 required)
#   ✗ Swedbank A (S27) 2023: Only 1 pages (min 50 required)
#   ✗ Telia Company (S29) 2020: Only 4 pages (min 50 required)
#   ✗ Telia Company (S29) 2024: Only 1 pages (min 50 required)

# %%
# Validate successful downloads, copy to companies_validated/{CID}/, and update coverage table
import importlib.util
from datetime import datetime

# Load validation function from scripts
validate_script_path = repo / 'scripts' / 'validate_reports.py'
spec = importlib.util.spec_from_file_location("validate_reports", validate_script_path)
validate_module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(validate_module)
validate_pdf = validate_module.validate_pdf

# Setup directories
validated_dir = repo / 'companies_validated'
validated_dir.mkdir(exist_ok=True)

# Reload coverage table (in case it was modified)
coverage_df = pd.read_csv(coverage_path, sep='\t')

validation_records = []

for _, dl in successes.iterrows():
    cid = dl['cid']
    company = dl['company']
    year = dl['year']
    output_path = dl.get('output_path', '')
    
    if not output_path:
        output_path = str(repo / 'companies' / cid / f"{cid}_{year}_Annual_Report.pdf")
    
    pdf_path = Path(output_path)
    
    if not pdf_path.exists():
        validation_records.append({
            'company': company, 'cid': cid, 'year': year,
            'valid': False, 'issues': 'file missing after download'
        })
        print(f"⚠ Missing file: {pdf_path}")
        continue

    # Run validation
    validation = validate_pdf(str(pdf_path), company_name=company, expected_year=year)
    is_valid = validation.get('valid', False)
    issues = '; '.join(validation.get('issues', [])) if validation.get('issues') else ''
    size_mb = os.path.getsize(pdf_path) / (1024 * 1024)
    
    validation_records.append({
        'company': company, 'cid': cid, 'year': year,
        'valid': is_valid, 'issues': issues,
        'confidence': validation.get('confidence'),
        'pages': validation.get('pages'),
        'size_mb': size_mb
    })

    if is_valid:
        # Copy to validated directory
        dest_dir = validated_dir / cid
        dest_dir.mkdir(exist_ok=True)
        dest_path = dest_dir / pdf_path.name
        dest_path.write_bytes(pdf_path.read_bytes())
        print(f"✓ Validated: {company} {year} ({validation.get('pages')} pages, {validation.get('confidence'):.1f}% confidence)")

        # Update coverage table
        mask = (coverage_df['Company_Identifier'] == cid) & (coverage_df['FiscalYear'] == year)
        coverage_df.loc[mask, 'Report_URL'] = dl.get('url', '')
        coverage_df.loc[mask, 'Source_Page'] = dl.get('source_page', '')
        coverage_df.loc[mask, 'Pages'] = validation.get('pages', '')
        coverage_df.loc[mask, 'Size_MB'] = f"{size_mb:.2f}"
        coverage_df.loc[mask, 'Validation_Status'] = 'Valid'
        coverage_df.loc[mask, 'Validation_Confidence'] = f"{validation.get('confidence', 0.0):.1f}%"
        coverage_df.loc[mask, 'Validation_Issues'] = issues
        coverage_df.loc[mask, 'Validation_Date'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        coverage_df.loc[mask, 'Priority'] = 'Complete ✓'
        coverage_df.loc[mask, 'CaptureStatus'] = 'Validated'
    else:
        print(f"✗ Failed validation: {company} {year} ({issues})")

# Summary
print('\n' + '=' * 50)
print('Validation Summary')
print('=' * 50)
valid_count = sum(1 for r in validation_records if r['valid'])
print(f"✓ Valid: {valid_count} / {len(validation_records)}")
print(f"✗ Invalid: {len(validation_records) - valid_count}")

if any(not r['valid'] for r in validation_records):
    print('\nInvalid reports:')
    for r in validation_records:
        if not r['valid']:
            print(f"  ✗ {r['company']} ({r['cid']}) {r['year']}: {r.get('issues','')}")

# Save updated coverage table
coverage_df.to_csv(coverage_path, sep='\t', index=False)
print(f"\n✓ Coverage table updated: {coverage_path}")
# Out:
# ✓ Validated: Addtech B 2019 (61 pages, 62.9% confidence)
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'https://www.addtech.com/fileadmin/user_upload/Addtech-Annual-Report-2019-2020.pdf' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'Report_URL'] = dl.get('url', '')
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:65: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'https://www.addtech.com/investors-and-media/annual-reports' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'Source_Page'] = dl.get('source_page', '')
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.17' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'Size_MB'] = f"{size_mb:.2f}"
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:68: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Valid' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'Validation_Status'] = 'Valid'
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:69: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '62.9%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'Validation_Confidence'] = f"{validation.get('confidence', 0.0):.1f}%"
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:70: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'Validation_Issues'] = issues
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:71: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2026-01-17 17:17:57' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'Validation_Date'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1967899169.py:73: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Validated' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   coverage_df.loc[mask, 'CaptureStatus'] = 'Validated'
# ✓ Validated: Addtech B 2020 (74 pages, 66.4% confidence)
# ✓ Validated: Addtech B 2021 (74 pages, 66.4% confidence)
# ✓ Validated: Addtech B 2022 (80 pages, 68.0% confidence)
# ✓ Validated: Addtech B 2024 (152 pages, 87.2% confidence)
# ✓ Validated: Addtech B 2023 (155 pages, 88.0% confidence)
# ✓ Validated: Alfa Laval 2019 (152 pages, 87.2% confidence)
# ✓ Validated: Alfa Laval 2020 (160 pages, 89.3% confidence)
# ✓ Validated: Alfa Laval 2021 (194 pages, 98.4% confidence)
# ✓ Validated: Alfa Laval 2023 (192 pages, 97.9% confidence)
# ✓ Validated: Alfa Laval 2024 (81 pages, 68.3% confidence)
# ✓ Validated: Alfa Laval 2022 (200 pages, 100.0% confidence)
# ✓ Validated: ASSA ABLOY B 2019 (108 pages, 75.5% confidence)
# ✓ Validated: ASSA ABLOY B 2020 (112 pages, 76.5% confidence)
# ✓ Validated: ASSA ABLOY B 2022 (116 pages, 77.6% confidence)
# ✓ Validated: ASSA ABLOY B 2021 (116 pages, 77.6% confidence)
# ✓ Validated: ASSA ABLOY B 2023 (116 pages, 77.6% confidence)
# ✓ Validated: ASSA ABLOY B 2024 (164 pages, 90.4% confidence)
# ✓ Validated: Atlas Copco A 2020 (144 pages, 85.1% confidence)
# ✓ Validated: Atlas Copco A 2019 (150 pages, 86.7% confidence)
# ✓ Validated: Atlas Copco A 2021 (148 pages, 86.1% confidence)
# ✓ Validated: Atlas Copco A 2022 (152 pages, 87.2% confidence)
# ✓ Validated: Atlas Copco A 2024 (169 pages, 91.7% confidence)
# ✓ Validated: Atlas Copco A 2023 (154 pages, 87.7% confidence)
# ✓ Validated: Boliden 2020 (124 pages, 79.7% confidence)
# ✓ Validated: Boliden 2021 (128 pages, 80.8% confidence)
# ✓ Validated: Boliden 2022 (136 pages, 82.9% confidence)
# ✓ Validated: Boliden 2023 (144 pages, 85.1% confidence)
# ✓ Validated: Epiroc A 2019 (140 pages, 84.0% confidence)
# ✓ Validated: Boliden 2024 (192 pages, 97.9% confidence)
# ✓ Validated: Epiroc A 2020 (152 pages, 87.2% confidence)
# ✓ Validated: Epiroc A 2021 (152 pages, 87.2% confidence)
# ✓ Validated: Epiroc A 2022 (164 pages, 90.4% confidence)
# ✓ Validated: EQT 2019 (143 pages, 84.8% confidence)
# ✓ Validated: EQT 2021 (180 pages, 94.7% confidence)
# ✓ Validated: Epiroc A 2023 (176 pages, 93.6% confidence)
# ✓ Validated: EQT 2022 (191 pages, 97.6% confidence)
# ✓ Validated: Epiroc A 2024 (212 pages, 100.0% confidence)
# ✓ Validated: EQT 2023 (171 pages, 92.3% confidence)
# ✓ Validated: EQT 2024 (194 pages, 98.4% confidence)
# ✓ Validated: Ericsson B 2019 (220 pages, 100.0% confidence)
# ✓ Validated: Ericsson B 2020 (216 pages, 100.0% confidence)
# ✓ Validated: Ericsson B 2021 (219 pages, 100.0% confidence)
# ✓ Validated: Ericsson B 2023 (241 pages, 100.0% confidence)
# ✓ Validated: Ericsson B 2022 (240 pages, 100.0% confidence)
# ✓ Validated: Ericsson B 2024 (244 pages, 100.0% confidence)
# ✓ Validated: Essity B 2022 (164 pages, 90.4% confidence)
# ✓ Validated: Essity B 2021 (148 pages, 86.1% confidence)
# ✓ Validated: Essity B 2023 (188 pages, 96.8% confidence)
# ✓ Validated: Evolution 2019 (116 pages, 77.6% confidence)
# ✓ Validated: Evolution 2020 (129 pages, 81.1% confidence)
# ✓ Validated: Essity B 2024 (192 pages, 97.9% confidence)
# ✓ Validated: Evolution 2022 (121 pages, 78.9% confidence)
# ✓ Validated: Evolution 2023 (121 pages, 78.9% confidence)
# ✓ Validated: Evolution 2024 (117 pages, 77.9% confidence)
# ✓ Validated: Hennes & Mauritz B 2019 (88 pages, 70.1% confidence)
# ✗ Failed validation: Hennes & Mauritz B 2020 (Company name "Hennes & Mauritz B" not found in PDF)
# ✓ Validated: Hennes & Mauritz B 2021 (118 pages, 78.1% confidence)
# ✗ Failed validation: Hennes & Mauritz B 2022 (Company name "Hennes & Mauritz B" not found in PDF)
# ✗ Failed validation: Hennes & Mauritz B 2023 (Company name "Hennes & Mauritz B" not found in PDF)
# ✓ Validated: Hexagon B 2019 (88 pages, 70.1% confidence)
# ✗ Failed validation: Hennes & Mauritz B 2024 (Company name "Hennes & Mauritz B" not found in PDF)
# ✓ Validated: Hexagon B 2020 (88 pages, 70.1% confidence)
# ✓ Validated: Hexagon B 2021 (88 pages, 70.1% confidence)
# ✓ Validated: Hexagon B 2022 (88 pages, 70.1% confidence)
# ✓ Validated: Hexagon B 2023 (148 pages, 86.1% confidence)
# ✓ Validated: Hexagon B 2024 (180 pages, 94.7% confidence)
# ✓ Validated: Evolution 2021 (117 pages, 77.9% confidence)
# ✓ Validated: Investor B 2020 (128 pages, 80.8% confidence)
# ✓ Validated: Investor B 2022 (156 pages, 88.3% confidence)
# ✓ Validated: Investor B 2021 (132 pages, 81.9% confidence)
# ✓ Validated: Investor B 2024 (172 pages, 92.5% confidence)
# ✓ Validated: Investor B 2023 (168 pages, 91.5% confidence)
# ✗ Failed validation: Lifco B 2020 (Year 2020 not found in PDF)
# ✓ Validated: Lifco B 2019 (104 pages, 74.4% confidence)
# ✓ Validated: Lifco B 2021 (120 pages, 78.7% confidence)
# ✓ Validated: Lifco B 2022 (156 pages, 88.3% confidence)
# ✓ Validated: Lifco B 2023 (158 pages, 88.8% confidence)
# ✓ Validated: NIBE Industrier B 2024 (200 pages, 100.0% confidence)
# ✓ Validated: Lifco B 2024 (154 pages, 87.7% confidence)
# ✗ Failed validation: Nordea Bank Abp 2019 (Company name "Nordea Bank Abp" not found in PDF)
# ✗ Failed validation: Nordea Bank Abp 2022 (Company name "Nordea Bank Abp" not found in PDF)
# ignore '/Perms' verify failed
# ignore '/Perms' verify failed
# ✗ Failed validation: Nordea Bank Abp 2023 (Company name "Nordea Bank Abp" not found in PDF)
# ✗ Failed validation: Nordea Bank Abp 2020 (Company name "Nordea Bank Abp" not found in PDF)
# ✓ Validated: SAAB B 2020 (166 pages, 90.9% confidence)
# ✓ Validated: SAAB B 2019 (152 pages, 87.2% confidence)
# ✗ Failed validation: Nordea Bank Abp 2024 (Company name "Nordea Bank Abp" not found in PDF)
# ✓ Validated: SAAB B 2022 (172 pages, 92.5% confidence)
# ✓ Validated: SAAB B 2024 (228 pages, 100.0% confidence)
# ✓ Validated: SAAB B 2023 (180 pages, 94.7% confidence)
# ✓ Validated: SAAB B 2021 (168 pages, 91.5% confidence)
# ✓ Validated: Sandvik 2020 (148 pages, 86.1% confidence)
# ✓ Validated: Sandvik 2021 (160 pages, 89.3% confidence)
# ✓ Validated: Sandvik 2023 (168 pages, 91.5% confidence)
# ✓ Validated: Sandvik 2022 (160 pages, 89.3% confidence)
# ✓ Validated: Sandvik 2024 (160 pages, 89.3% confidence)
# ✓ Validated: SCA B 2019 (168 pages, 91.5% confidence)
# ✓ Validated: SCA B 2020 (180 pages, 94.7% confidence)
# ✓ Validated: SCA B 2023 (196 pages, 98.9% confidence)
# ✓ Validated: SCA B 2024 (202 pages, 100.0% confidence)
# ✓ Validated: SEB A 2024 (307 pages, 100.0% confidence)
# ✓ Validated: SCA B 2022 (192 pages, 97.9% confidence)
# ✓ Validated: Skanska B 2022 (224 pages, 100.0% confidence)
# ✓ Validated: Skanska B 2023 (226 pages, 100.0% confidence)
# ✓ Validated: Skanska B 2024 (232 pages, 100.0% confidence)
# ✓ Validated: SKF B 2020 (162 pages, 89.9% confidence)
# ✓ Validated: SKF B 2021 (162 pages, 89.9% confidence)
# ✓ Validated: SKF B 2022 (150 pages, 86.7% confidence)
# ✗ Failed validation: Sv. Handelsbanken A 2019 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✓ Validated: SKF B 2023 (160 pages, 89.3% confidence)
# ✓ Validated: SKF B 2024 (175 pages, 93.3% confidence)
# ✗ Failed validation: Sv. Handelsbanken A 2020 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✗ Failed validation: Sv. Handelsbanken A 2021 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✗ Failed validation: Sv. Handelsbanken A 2022 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✗ Failed validation: Sv. Handelsbanken A 2023 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✗ Failed validation: Sv. Handelsbanken A 2024 (Company name "Sv. Handelsbanken A" not found in PDF)
# ✓ Validated: Swedbank A 2021 (256 pages, 100.0% confidence)
# ✓ Validated: Swedbank A 2024 (386 pages, 100.0% confidence)
# ✓ Validated: Tele2 B 2020 (136 pages, 82.9% confidence)
# ✓ Validated: Swedbank A 2022 (260 pages, 100.0% confidence)
# ✓ Validated: Tele2 B 2019 (94 pages, 71.7% confidence)
# ✓ Validated: Tele2 B 2021 (151 pages, 86.9% confidence)
# ✓ Validated: Tele2 B 2024 (211 pages, 100.0% confidence)
# ✓ Validated: Tele2 B 2022 (162 pages, 89.9% confidence)
# ✓ Validated: Telia Company 2019 (241 pages, 100.0% confidence)
# ✓ Validated: Tele2 B 2023 (164 pages, 90.4% confidence)
# ✓ Validated: Telia Company 2021 (266 pages, 100.0% confidence)
# ✓ Validated: Telia Company 2022 (263 pages, 100.0% confidence)
# ✓ Validated: Telia Company 2023 (271 pages, 100.0% confidence)
# ✓ Validated: Volvo B 2019 (230 pages, 100.0% confidence)
# ✓ Validated: Volvo B 2020 (210 pages, 100.0% confidence)
# ✓ Validated: Volvo B 2021 (218 pages, 100.0% confidence)
# ✓ Validated: Volvo B 2022 (226 pages, 100.0% confidence)
# ✓ Validated: Volvo B 2023 (232 pages, 100.0% confidence)
# ✓ Validated: Volvo B 2024 (220 pages, 100.0% confidence)
#
# ==================================================
# Validation Summary
# ==================================================
# ✓ Valid: 119 / 135
# ✗ Invalid: 16
#
# Invalid reports:
#   ✗ Hennes & Mauritz B (S13) 2020: Company name "Hennes & Mauritz B" not found in PDF
#   ✗ Hennes & Mauritz B (S13) 2022: Company name "Hennes & Mauritz B" not found in PDF
#   ✗ Hennes & Mauritz B (S13) 2023: Company name "Hennes & Mauritz B" not found in PDF
#   ✗ Hennes & Mauritz B (S13) 2024: Company name "Hennes & Mauritz B" not found in PDF
#   ✗ Lifco B (S17) 2020: Year 2020 not found in PDF
#   ✗ Nordea Bank Abp (S19) 2019: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Nordea Bank Abp (S19) 2022: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Nordea Bank Abp (S19) 2023: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Nordea Bank Abp (S19) 2020: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Nordea Bank Abp (S19) 2024: Company name "Nordea Bank Abp" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2019: Company name "Sv. Handelsbanken A" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2020: Company name "Sv. Handelsbanken A" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2021: Company name "Sv. Handelsbanken A" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2022: Company name "Sv. Handelsbanken A" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2023: Company name "Sv. Handelsbanken A" not found in PDF
#   ✗ Sv. Handelsbanken A (S26) 2024: Company name "Sv. Handelsbanken A" not found in PDF
#
# ✓ Coverage table updated: /Users/jakobjohannesson/Documents/github_repos/aspiratio/coverage_table_updated.csv

# %%
# Append new validation records to validation_results.csv
if validation_records:
    new_records = []
    for r in validation_records:
        if r['valid']:
            cid = r['cid']
            year = r['year']
            company = r['company']
            pdf_name = f"{cid}_{year}_Annual_Report.pdf"
            
            # Find the download result for this record
            dl_info = successes[(successes['cid'] == cid) & (successes['year'] == year)].iloc[0] if len(successes[(successes['cid'] == cid) & (successes['year'] == year)]) > 0 else {}
            
            new_records.append({
                'CID': cid,
                'Company_Name': company,
                'Year': year,
                'Filename': pdf_name,
                'Valid': True,
                'Confidence': r.get('confidence', 0),
                'Pages': r.get('pages', 0),
                'Company_Found': True,
                'Year_Found': True,
                'Issues': r.get('issues', ''),
                'Source_Path': f"companies/{cid}/{pdf_name}",
                'Validated_Date': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
                'IR_URL': dl_info.get('source_page', '') if isinstance(dl_info, dict) else (dl_info['source_page'] if 'source_page' in dl_info.index else ''),
                'Pattern_Type': 'Downloaded via notebook'
            })
    
    if new_records:
        # Load existing validation results
        existing_validation = pd.read_csv(validation_path)
        new_df = pd.DataFrame(new_records)
        
        # Remove duplicates (in case we're re-running)
        existing_keys = set(zip(existing_validation['CID'], existing_validation['Year']))
        new_df = new_df[~new_df.apply(lambda r: (r['CID'], r['Year']) in existing_keys, axis=1)]
        
        if len(new_df) > 0:
            updated_validation = pd.concat([existing_validation, new_df], ignore_index=True)
            updated_validation.to_csv(validation_path, index=False)
            print(f"✓ Added {len(new_df)} new records to validation_results.csv")
        else:
            print("ℹ All validated records already exist in validation_results.csv")
else:
    print("ℹ No validation records to add")
# Out:
# ✓ Added 119 new records to validation_results.csv
# /var/folders/t2/wr5tn7h97pdb6tkkgvr3xqf00000gn/T/ipykernel_78465/1188981406.py:41: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   updated_validation = pd.concat([existing_validation, new_df], ignore_index=True)
